# %% [markdown]
# # Big Data Coursework - Questions
#
# ## Data Processing and Machine Learning in the Cloud
#
# This is the **INM432 Big Data coursework 2023**.
# This coursework contains extended elements of **theory** and **practice**, mainly around parallelisation of tasks withSpark and a bit about parallel training using TensorFlow.
#
# ## Code and Report
#
# Your tasks parallelization of tasks in PySpark, extension, evaluation, and theoretical reflection.
# Please complete and submit the **coding tasks** in a copy of **this notebook**.
# Write your code in the **indicated cells** and **include** the **output** in the submitted notebook.
# Make sure that **your code contains comments** on its **stucture** and explanations of its **purpose**.
#
# Provide also a **report** with the **textual answers in a separate document**.
# Include **screenshots** from the Google Cloud web interface (don't use the SCREENSHOT function that Google provides, but take a picture of the graphs you see for the VMs) and result tables, as well as written text about the analysis.
#
# ## Submission
#
# Download and submit **your version of this notebook** as an **.ipynb** file and also submit a **shareable link** to your notebook on Colab in your report (created with the Colab 'Share' function) (**and don’t change the online version after submission**).
#
# Further, provide your **report as a PDF document**. **State the number of words** in the document at the end. The report should **not have more than 2000 words**.

# %% [markdown]
# ## Introduction and Description
#
# This coursework focuses on parallelisation and scalability in the cloud with Spark and TesorFlow/Keras.
# We start with code based on **lessons 3 and 4** of the [*Fast and Lean Data Science*](https://github.com/GoogleCloudPlatform/training-data-analyst/tree/master/courses/fast-and-lean-data-science) course by Martin Gorner.
# The course is based on Tensorflow for data processing and MachineLearning.
# Tensorflow's data processing approach is somewhat similar to that of Spark, but you don't need to study Tensorflow, just make sure you understand the high-level structure.
# What we will do here is **parallelising** **pre-processing**, and **measuring** performance, and we will perform **evaluation** and **analysis** on the cloud performance, as well as **theoretical discussion**.
#
# This coursework contains **3 sections**.
#
# ### Section 0
#
# This section just contains some necessary code for setting up the environment. It has no tasks for you (but do read the code and comments).
#
# ### Section 1
# Section 1 is about preprocessing a set of image files.
# We will work with a public dataset “Flowers” (3600 images, 5 classes).
# This is not a vast dataset, but it keeps the tasks more manageable for development and you can scale up later, if you like.
#
# In **'Getting Started'** we will work through the data preprocessing code from *Fast and Lean Data Science* which uses TensorFlow's `tf.data` package.
# There is no task for you here, but you will need to re-use some of this code later.
#
# In **Task 1** you will **parallelise the data preprocessing in Spark**, using Google Cloud (GC) Dataproc.
# This involves adapting the code from 'Getting Started' to use Spark and running it in the cloud.
#
# ### Section 2
# In **Section 2** we are going to **measure the speed of reading data** in the cloud. In **Task  2** we will **paralellize the measuring** of different configurations **using Spark**.
#
# ### Section 3
#
# This section is about the theoretical discussion, based on to two papers, in **Task 3**. The answers should be given in the PDF report.
#
# ### General points
#
# For **all coding tasks**, take the **time of the operations** and for the cloud operations, get performance **information from the web interfaces** for your reporting and analysis.
#
# The **tasks** are **mostly independent** of each other. The later tasks can mostly be addressed without needing the solution to the earlier ones.

# %% [markdown]
# # Section 0: Set-up
#
# As usual, you need to run the **imports and authentication every time you work with this notebook**. Use the **local Spark** installation for development before you send jobs to the cloud.
#
# Read through this section once and **fill in the project ID the first time**, then you can just step straight throught this at the beginning of each session - except for the two authentication cells.

# %% [markdown]
# ### Imports
#
# We import some **packages that will be needed throughout**.
# For the **code that runs in the cloud**, we will need **separate import sections** that will need to be partly different from the one below.

# %%
import os, sys, math
import numpy as np
import scipy as sp
import scipy.stats
import time
import datetime
import string
import random
from matplotlib import pyplot as plt
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
import pickle
# Out:
# Tensorflow version 2.12.0

# %% [markdown]
# ### Cloud and Drive authentication
#
# This is for **authenticating with with GCS Google Drive**, so that we can create and use our own buckets and access Dataproc and AI-Platform.
#
# This section **starts with the two interactive authentications**.
#
# First, we mount Google Drive for persistent local storage and create a directory `BD-CW` thay you can use for this work.
# Then we'll set up the cloud environment, including a storage bucket.

# %%
print('Mounting google drive...')
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive"
# !mkdir BD-CW
# %cd "/content/drive/MyDrive/BD-CW"
# Out:
# Mounting google drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# mkdir: cannot create directory ‘BD-CW’: File exists
# /content/drive/MyDrive/BD-CW

# %% [markdown]
# Next, we authenticate with the GCS to enable access to Dataproc and AI-Platform.

# %%
import sys
if 'google.colab' in sys.modules:
    from google.colab import auth
    auth.authenticate_user()

# %% [markdown]
# It is useful to **create a new Google Cloud project** for this coursework. You can do this on the [GC Console page](https://console.cloud.google.com) by clicking on the entry at the top, right of the *Google Cloud Platform* and choosing *New Project*. **Copy** the **generated project ID** to the next cell. Also **enable billing** and the **Compute, Storage and Dataproc** APIs like we did during the labs.
#
# We also specify the **default project and region**. The REGION should be `us-central1` as that seems to be the only one that reliably works with the free credit.
# This way we don't have to specify this information every time we access the cloud.

# %%
PROJECT = 'big-data-adcy439'  ### USE YOUR GOOGLE CLOUD PROJECT ID HERE. ### 
# !gcloud config set project $PROJECT
REGION = 'us-central1'
CLUSTER = '{}-cluster'.format(PROJECT)
# !gcloud config set compute/region $REGION
# !gcloud config set dataproc/region $REGION

# !gcloud config list # show some information
# Out:
# Updated property [core/project].
# Updated property [compute/region].
# Updated property [dataproc/region].
# [component_manager]
# disable_update_check = True
# [compute]
# region = us-central1
# [core]
# account = taherzadehshivaa@gmail.com
# project = big-data-adcy439
# [dataproc]
# region = us-central1
#
# Your active configuration is: [default]

# %% [markdown]
# With the cell below, we **create a storage bucket** that we will use later for **global storage**.
# If the bucket exists you will see a "ServiceException: 409 ...", which does not cause any problems.
# **You must create your own bucket to have write access.**

# %%
BUCKET = 'gs://{}-storage'.format(PROJECT)
# !gsutil mb $BUCKET
# Out:
# Creating gs://big-data-adcy439-storage/...
# ServiceException: 409 A Cloud Storage bucket named 'big-data-adcy439-storage' already exists. Try another name. Bucket names must be globally unique across all Google Cloud projects, including those outside of your organization.

# %% [markdown]
# The cell below just **defines some routines for displaying images** that will be **used later**. You can see the code by double-clicking, but you don't need to study this.

# %%
#@title Utility functions for image display **[RUN THIS TO ACTIVATE]** { display-mode: "form" }
def display_9_images_from_dataset(dataset):
  plt.figure(figsize=(13,13))
  subplot=331
  for i, (image, label) in enumerate(dataset):
    plt.subplot(subplot)
    plt.axis('off')
    plt.imshow(image.numpy().astype(np.uint8))   
    plt.title(str(label.numpy()), fontsize=16)
    # plt.title(label.numpy().decode(), fontsize=16)
    subplot += 1
    if i==8:
      break
  plt.tight_layout()
  plt.subplots_adjust(wspace=0.1, hspace=0.1)
  plt.show()

def display_training_curves(training, validation, title, subplot):
  if subplot%10==1: # set up the subplots on the first call
    plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
    plt.tight_layout()
  ax = plt.subplot(subplot)
  ax.set_facecolor('#F8F8F8')
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['train', 'valid.'])

def dataset_to_numpy_util(dataset, N):
    dataset = dataset.batch(N)
    for images, labels in dataset:
        numpy_images = images.numpy()
        numpy_labels = labels.numpy()
        break;
    return numpy_images, numpy_labels

def title_from_label_and_target(label, correct_label):
  correct = (label == correct_label)
  return "{} [{}{}{}]".format(CLASSES[label], str(correct), ', shoud be ' if not correct else '',
                              CLASSES[correct_label] if not correct else ''), correct

def display_one_flower(image, title, subplot, red=False):
    plt.subplot(subplot)
    plt.axis('off')
    plt.imshow(image)
    plt.title(title, fontsize=16, color='red' if red else 'black')
    return subplot+1

def display_9_images_with_predictions(images, predictions, labels):
  subplot=331
  plt.figure(figsize=(13,13))
  classes = np.argmax(predictions, axis=-1)
  for i, image in enumerate(images):
    title, correct = title_from_label_and_target(classes[i], labels[i])
    subplot = display_one_flower(image, title, subplot, not correct)
    if i >= 8:
      break;
              
  plt.tight_layout()
  plt.subplots_adjust(wspace=0.1, hspace=0.1)
  plt.show()

# %% [markdown]
# ### Install Spark locally for quick testing
#
# You can use the cell below to **install Spark locally on this Colab VM** (like in the labs), to do quicker small-scale interactive testing. Using Spark in the cloud with **Dataproc is still required for the final version**.

# %%
# %cd
# !apt-get update -qq
# !apt-get install openjdk-8-jdk-headless -qq >> /dev/null # send any output to null device
# !tar -xzf "/content/drive/My Drive/Big_Data/data/spark/spark-3.2.0-bin-hadoop2.7.tgz" # unpack 

# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/root/spark-3.2.0-bin-hadoop2.7"
import findspark
findspark.init()
import pyspark
print(pyspark.__version__)
sc = pyspark.SparkContext.getOrCreate()
print(sc)
# Out:
# /root
# 3.2.0
# <SparkContext master=local[*] appName=pyspark-shell>

# %% [markdown]
# # Section 1: Data pre-processing
#
# This section is about the **pre-processing of a dataset** for deep learning.
# We first look at a ready-made solution using Tensorflow and then we build a implement the same process with Spark.
# The tasks are about **parallelisation** and **analysis** the performance of the cloud implementations.

# %% [markdown]
# ## 1.1 Getting started
#
# In this section, we get started with the data pre-processing. The code is based on lecture 3 of the 'Fast and Lean Data Science' course.
#
# **This code is using the TensorFlow** `tf.data` package, which supports map functions, similar to Spark. Your **task** will be to **re-implement the same approach in Spark**.

# %% [markdown]
# We start by **setting some variables for the *Flowers* dataset**.

# %%
GCS_PATTERN = 'gs://flowers-public/*/*.jpg' # glob  pattern for input files
PARTITIONS = 16 # no of partitions we will use later 
TARGET_SIZE = [192, 192] # target resolution for the images
CLASSES = [b'daisy', b'dandelion', b'roses', b'sunflowers', b'tulips']
    # labels for the data

# %% [markdown]
# We **read the image files** from the public GCS bucket that contains the *Flowers* dataset.
# **TensorFlow** has **functions** to execute glob patterns that we use to calculate the the number of images in total and per partition (rounded up as we cannont deal with parts of images).

# %%
nb_images = len(tf.io.gfile.glob(GCS_PATTERN)) # number of images
partition_size = math.ceil(1.0 * nb_images / PARTITIONS) # images per partition (float)
print("GCS_PATTERN matches {} images, to be divided into {} partitions with up to {} images each.".format(nb_images, PARTITIONS, partition_size))
# Out:
# GCS_PATTERN matches 3670 images, to be divided into 16 partitions with up to 230 images each.

# %% [markdown]
# ### Map functions
#
# In order to read use the images for learning, they need to be **preprocessed** (decoded, resized, cropped, and potentially recompressed).
# Below are **map functions** for these steps.
# You **don't need to study** the **internals of these functions** in detail.

# %%
def decode_jpeg_and_label(filepath):
    # extracts the image data and creates a class label, based on the filepath 
    bits = tf.io.read_file(filepath)
    image = tf.image.decode_jpeg(bits)
    # parse flower name from containing directory
    label = tf.strings.split(tf.expand_dims(filepath, axis=-1), sep='/')
    label2 = label.values[-2]
    return image, label2

def resize_and_crop_image(image, label):
    # Resizes and cropd using "fill" algorithm:
    # always make sure the resulting image is cut out from the source image 
    # so that it fills the TARGET_SIZE entirely with no black bars 
    # and a preserved aspect ratio.
    w = tf.shape(image)[0]
    h = tf.shape(image)[1]
    tw = TARGET_SIZE[1]
    th = TARGET_SIZE[0]
    resize_crit = (w * th) / (h * tw)
    image = tf.cond(resize_crit < 1,
                    lambda: tf.image.resize(image, [w*tw/w, h*tw/w]), # if true
                    lambda: tf.image.resize(image, [w*th/h, h*th/h])  # if false
                    )
    nw = tf.shape(image)[0]
    nh = tf.shape(image)[1]
    image = tf.image.crop_to_bounding_box(image, (nw - tw) // 2, (nh - th) // 2, tw, th)
    return image, label

def recompress_image(image, label):
    # this reduces the amount of data, but takes some time
    image = tf.cast(image, tf.uint8)
    image = tf.image.encode_jpeg(image, optimize_size=True, chroma_downsampling=False)
    return image, label

# %% [markdown]
# With `tf.data`, we can apply decoding and resizing as map functions.

# %%
dsetFiles = tf.data.Dataset.list_files(GCS_PATTERN) # This also shuffles the images
dsetDecoded = dsetFiles.map(decode_jpeg_and_label)
dsetResized = dsetDecoded.map(resize_and_crop_image)

# %% [markdown]
# We can also look at some images using the image display function defined above (the one with the hidden code).

# %%
display_9_images_from_dataset(dsetResized)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Now, let's test continuous reading from the dataset. We can see that reading the first 100 files already takes some time.

# %%
time_before=time.time()
sample_set = dsetResized.batch(10).take(10) # take 10 batches of 10 images for testing
for image, label in sample_set: 
    print("Image batch shape {}, {})".format(image.numpy().shape,
        [lbl.decode('utf8') for lbl in label.numpy()]))
time_after=time.time()
time_spent=time_after-time_before
time_spent
# Out:
# Image batch shape (10, 192, 192, 3), ['sunflowers', 'dandelion', 'tulips', 'sunflowers', 'dandelion', 'tulips', 'daisy', 'dandelion', 'daisy', 'roses'])
# Image batch shape (10, 192, 192, 3), ['sunflowers', 'daisy', 'sunflowers', 'tulips', 'daisy', 'sunflowers', 'tulips', 'tulips', 'tulips', 'tulips'])
# Image batch shape (10, 192, 192, 3), ['tulips', 'dandelion', 'dandelion', 'tulips', 'sunflowers', 'tulips', 'roses', 'sunflowers', 'daisy', 'dandelion'])
# Image batch shape (10, 192, 192, 3), ['daisy', 'dandelion', 'sunflowers', 'dandelion', 'tulips', 'tulips', 'sunflowers', 'dandelion', 'sunflowers', 'daisy'])
# Image batch shape (10, 192, 192, 3), ['daisy', 'dandelion', 'tulips', 'dandelion', 'daisy', 'daisy', 'roses', 'roses', 'tulips', 'dandelion'])
# Image batch shape (10, 192, 192, 3), ['dandelion', 'dandelion', 'roses', 'dandelion', 'dandelion', 'roses', 'tulips', 'tulips', 'sunflowers', 'dandelion'])
# Image batch shape (10, 192, 192, 3), ['dandelion', 'daisy', 'sunflowers', 'dandelion', 'tulips', 'roses', 'sunflowers', 'daisy', 'tulips', 'dandelion'])
# Image batch shape (10, 192, 192, 3), ['daisy', 'daisy', 'dandelion', 'sunflowers', 'sunflowers', 'tulips', 'daisy', 'tulips', 'dandelion', 'sunflowers'])
# Image batch shape (10, 192, 192, 3), ['dandelion', 'roses', 'sunflowers', 'roses', 'dandelion', 'tulips', 'sunflowers', 'daisy', 'dandelion', 'dandelion'])
# Image batch shape (10, 192, 192, 3), ['dandelion', 'dandelion', 'sunflowers', 'daisy', 'dandelion', 'daisy', 'roses', 'daisy', 'dandelion', 'roses'])
# 5.024407148361206

# %% [markdown]
# ## 1.2 Improving Speed
#
# Using individual image files didn't look very fast. The 'Lean and Fast Data Science' course introduced **two techniques to improve the speed**.

# %% [markdown]
# ### Recompress the images
# By **compressing** the images in the **reduced resolution** we save on the size.
# This **costs some CPU time** upfront, but **saves network and disk bandwith**, especially when the data are **read multiple times**.

# %%
time_before=time.time()
# This is a quick test to get an idea how long recompressions takes.  
dataset4 = dsetResized.map(recompress_image)
test_set = dataset4.batch(10).take(10)
for image, label in test_set:
    print("Image batch shape {}, {})".format(image.numpy().shape, [lbl.decode('utf8') for lbl in label.numpy()])) 
time_after=time.time()
time_spent=time_after-time_before
time_spent
# Out:
# Image batch shape (10,), ['daisy', 'sunflowers', 'dandelion', 'tulips', 'daisy', 'sunflowers', 'tulips', 'daisy', 'sunflowers', 'dandelion'])
# Image batch shape (10,), ['dandelion', 'tulips', 'roses', 'daisy', 'sunflowers', 'roses', 'sunflowers', 'daisy', 'roses', 'tulips'])
# Image batch shape (10,), ['sunflowers', 'dandelion', 'roses', 'tulips', 'daisy', 'sunflowers', 'tulips', 'dandelion', 'sunflowers', 'roses'])
# Image batch shape (10,), ['roses', 'dandelion', 'sunflowers', 'roses', 'daisy', 'sunflowers', 'sunflowers', 'dandelion', 'roses', 'sunflowers'])
# Image batch shape (10,), ['roses', 'roses', 'daisy', 'dandelion', 'daisy', 'dandelion', 'sunflowers', 'sunflowers', 'roses', 'roses'])
# Image batch shape (10,), ['sunflowers', 'daisy', 'tulips', 'roses', 'roses', 'roses', 'roses', 'dandelion', 'dandelion', 'daisy'])
# Image batch shape (10,), ['dandelion', 'sunflowers', 'daisy', 'tulips', 'dandelion', 'roses', 'roses', 'daisy', 'daisy', 'daisy'])
# Image batch shape (10,), ['daisy', 'dandelion', 'roses', 'dandelion', 'sunflowers', 'daisy', 'roses', 'sunflowers', 'dandelion', 'dandelion'])
# Image batch shape (10,), ['dandelion', 'roses', 'sunflowers', 'roses', 'tulips', 'tulips', 'daisy', 'dandelion', 'dandelion', 'sunflowers'])
# Image batch shape (10,), ['tulips', 'dandelion', 'dandelion', 'dandelion', 'daisy', 'sunflowers', 'dandelion', 'roses', 'dandelion', 'tulips'])
# 4.657508611679077

# %% [markdown]
# ### Write the dataset to TFRecord files
#
# By writing **multiple preprocessed samples into a single file**, we can make further speed gains.
# We distribute the data over **partitions** to facilitate **parallelisation** when the data are used.
# First we need to **define a location** where we want to put the file.

# %%
GCS_OUTPUT = BUCKET + '/tfrecords-jpeg-192x192-2/flowers'  # prefix for output file names

# %% [markdown]
# Now we can **write the TFRecord files** to the bucket.
#
# Running the cell takes some time and **only needs to be done once** or not at all, as you can use the publicly available data for the next few cells. For convenience I have commented out the call to `write_tfrecords` at the end of the next cell. You don't need to run it (it takes some time), but you'll need to use the code below later (but there is no need to study it in detail).
#
# There is a **ready-made pre-processed data** versions available here:
# `gs://flowers-public/tfrecords-jpeg-192x192-2/`, that we can use for testing.

# %%
# functions for writing TFRecord entries
# Feature values are always stored as lists, a single data element will be a list of size 1
def _bytestring_feature(list_of_bytestrings):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=list_of_bytestrings))

def _int_feature(list_of_ints): # int64
    return tf.train.Feature(int64_list=tf.train.Int64List(value=list_of_ints))  

def to_tfrecord(tfrec_filewriter, img_bytes, label): # Create tf data records 
    class_num = np.argmax(np.array(CLASSES)==label) # 'roses' => 2 (order defined in CLASSES)
    one_hot_class = np.eye(len(CLASSES))[class_num]     # [0, 0, 1, 0, 0] for class #2, roses
    feature = {
        "image": _bytestring_feature([img_bytes]), # one image in the list
        "class": _int_feature([class_num]) #,      # one class in the list
    }
    return tf.train.Example(features=tf.train.Features(feature=feature))

def write_tfrecords(GCS_PATTERN,GCS_OUTPUT,partition_size): # write the images to files. 
    print("Writing TFRecords")
    tt0 = time.time()
    filenames = tf.data.Dataset.list_files(GCS_PATTERN) 
    dataset1 = filenames.map(decode_jpeg_and_label)
    dataset2 = dataset1.map(resize_and_crop_image)  
    dataset3 = dataset2.map(recompress_image)
    dataset4 = dataset3.batch(partition_size) # partitioning: there will be one "batch" of images per file 
    for partition, (image, label) in enumerate(dataset4):
        # batch size used as partition size here
        partition_size = image.numpy().shape[0]
        # good practice to have the number of records in the filename
        filename = GCS_OUTPUT + "{:02d}-{}.tfrec".format(partition, partition_size)
        # You need to change GCS_OUTPUT to your own bucket to actually create new files  
        with tf.io.TFRecordWriter(filename) as out_file:
            for i in range(partition_size):
                example = to_tfrecord(out_file,
                                    image.numpy()[i], # re-compressed image: already a byte string
                                    label.numpy()[i] #
                                    )
                out_file.write(example.SerializeToString())
        print("Wrote file {} containing {} records".format(filename, partition_size))
    print("Total time: "+str(time.time()-tt0))

#write_tfrecords(GCS_PATTERN,GCS_OUTPUT,partition_size) # uncomment to run this cell

# %% [markdown]
# ### Test the TFRecord files
#
# We can now **read from the TFRecord files**. By default, we use the files in the public bucket. Comment out the 1st line of the cell below to use the files written in the cell above.

# %%
# GCS_OUTPUT = 'gs://flowers-public/tfrecords-jpeg-192x192-2/' 
# remove the line above to use your own files that you generated above

def read_tfrecord(example):
    features = {
        "image": tf.io.FixedLenFeature([], tf.string),  # tf.string = bytestring (not text string)
        "class": tf.io.FixedLenFeature([], tf.int64) #,   # shape [] means scalar
    }
    # decode the TFRecord
    example = tf.io.parse_single_example(example, features)
    image = tf.image.decode_jpeg(example['image'], channels=3)
    image = tf.reshape(image, [*TARGET_SIZE, 3])    
    class_num = example['class']
    return image, class_num 

def load_dataset(filenames):
    # read from TFRecords. For optimal performance, read from multiple    
    # TFRecord files at once and set the option experimental_deterministic = False
    # to allow order-altering optimizations.
    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = False

    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.with_options(option_no_order)
    dataset = dataset.map(read_tfrecord)
    return dataset

    
filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
datasetTfrec = load_dataset(filenames)

# %% [markdown]
# Let's have a look **if reading from the TFRecord** files is **quicker**.

# %%
time_before=time.time()
batched_dataset = datasetTfrec.batch(10)
sample_set = batched_dataset.take(10)
for image, label in sample_set: 
    print("Image batch shape {}, {})".format(image.numpy().shape, \
                        [str(lbl) for lbl in label.numpy()]))
time_after=time.time()
time_spent=time_after-time_before
time_spent
# Out:
# Image batch shape (10, 192, 192, 3), ['4', '1', '2', '4', '1', '3', '3', '4', '1', '1'])
# Image batch shape (10, 192, 192, 3), ['4', '3', '3', '1', '1', '0', '0', '3', '4', '1'])
# Image batch shape (10, 192, 192, 3), ['1', '0', '3', '4', '2', '2', '2', '0', '0', '2'])
# Image batch shape (10, 192, 192, 3), ['3', '0', '4', '4', '0', '2', '2', '2', '2', '2'])
# Image batch shape (10, 192, 192, 3), ['1', '4', '2', '3', '1', '2', '0', '4', '4', '1'])
# Image batch shape (10, 192, 192, 3), ['1', '0', '2', '4', '1', '2', '1', '2', '4', '1'])
# Image batch shape (10, 192, 192, 3), ['0', '3', '1', '3', '2', '4', '4', '2', '4', '0'])
# Image batch shape (10, 192, 192, 3), ['1', '1', '3', '4', '1', '3', '4', '1', '4', '1'])
# Image batch shape (10, 192, 192, 3), ['4', '1', '3', '2', '1', '4', '4', '0', '2', '2'])
# Image batch shape (10, 192, 192, 3), ['4', '2', '3', '4', '2', '4', '4', '1', '0', '2'])
# 0.640528678894043

# %% [markdown]
# Wow, we have a **massive speed-up**! The repackageing is worthwhile :-)

# %% [markdown]
# ## Task 1: Write TFRecord files to the cloud with Spark (40%)
#
# Since recompressing and repackaging is very effective, we would like to be able to do it inparallel for large datasets.
# This is a relatively straightforward case of **parallelisation**.
# We will **use Spark to implement** the same process as above, but in parallel.

# %% [markdown]
# ### 1a)	Create the script (14%)
#
# **Re-implement** the pre-processing in Spark, using Spark mechanisms for **distributing** the workload **over multiple machines**.
#
# You need to:
#
# i) **Copy** over the **mapping functions** (see section 1.1) and **adapt** the resizing and recompression functions **to Spark** (only one argument). (3%)
#
# ii) **Replace** the TensorFlow **Dataset objects with RDDs**, starting with an RDD that contains the list of image filenames. (3%)
#
# iii) **Sample** the the RDD to a smaller number at an appropriate position in the code. Specify a sampling factor of 0.02 for short tests. (1%)
#
# iv) Then **use the functions from above** to write the TFRecord files. (3%)
#
# v) The code for **writing to the TFRecord files** needs to be put into a function, that can be applied to every partition with the ['RDD.mapPartitionsWithIndex'](https://spark.apache.org/docs/2.4.8/api/python/pyspark.html#pyspark.RDD.mapPartitionsWithIndex) function.
# The return value of that function is not used here, but you should return the filename, so that you have a list of the created TFRecord files. (4%)

# %%
# 1)a)i :

def resize_and_crop_2 (x):   
  image,label=x
  image,label=resize_and_crop_image(image,label) # creating a tuple of image and label
  return (image,label) # returning a tuple of image and label

def recompress_2 (y):
  image,label=y
  image,label=recompress_image(image,label) # creating a tuple of image and label
  return(image,label) # returning a tuple of image and label

# %%
# 1)a)ii :

GCS_PATTERN_RI= GCS_PATTERN # gets the pattern
filenames=tf.io.gfile.glob(GCS_PATTERN_RI) # 'tf.io.gfile.glob' gets the pattern and gives the raw image addresses
print(filenames[0]) # printing the first filename
RDD=sc.parallelize(filenames) # creating a RDD of filenames
# Out:
# gs://flowers-public/daisy/100080576_f52e8ee070_n.jpg

# %%
# 1)a)iii :

RDD_sample=RDD.sample(False,0.02) # getting a sample , 'False' so that samples are unique

# %%
# 1)a)iv :

RDD_decoded=RDD_sample.map(decode_jpeg_and_label) # mapping filenames to image and label
RDD_resized=RDD_decoded.map(resize_and_crop_2) # resizing the images 
RDD_recompressed=RDD_resized.map(recompress_2) # compressing the images
data = RDD_recompressed.collect()
GCS_OUTPUT = BUCKET + '/tfrecords-jpeg-192x192-2-test/flowers'

# %%
# 1)a)iv : ( continue ... writing tfrecord files):
tt0 = time.time() # for getting the time

for index, (image, label) in enumerate(data):
  # batch size used as partition size here
  # good practice to have the number of records in the filename
  filename = GCS_OUTPUT + "{}.tfrec".format(index)
  # You need to change GCS_OUTPUT to your own bucket to actually create new files  
  with tf.io.TFRecordWriter(filename) as out_file:
    example = to_tfrecord(out_file,
                        image.numpy(), # re-compressed image: already a byte string
                        label.numpy() #
                        )
    out_file.write(example.SerializeToString())
  print("Wrote file {} records".format(filename))
print("Total time: "+str(time.time()-tt0))
# Out:
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers0.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers1.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers2.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers3.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers4.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers5.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers6.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers7.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers8.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers9.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers10.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers11.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers12.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers13.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers14.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers15.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers16.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers17.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers18.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers19.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers20.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers21.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers22.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers23.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers24.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers25.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers26.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers27.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers28.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers29.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers30.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers31.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers32.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers33.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers34.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers35.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers36.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers37.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers38.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers39.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers40.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers41.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers42.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers43.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers44.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers45.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers46.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers47.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers48.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers49.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers50.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers51.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers52.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers53.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers54.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers55.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers56.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers57.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers58.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers59.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers60.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers61.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers62.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers63.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers64.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers65.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers66.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers67.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers68.tfrec records
# Wrote file gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers69.tfrec records
# Total time: 30.37706184387207

# %%
# 1)a)v:

def write_tfrecords_spark(partition, data): 
  tt0 = time.time() # for getting the time
  filename = GCS_OUTPUT + '/tfrecords-test/flowers' + "-spark-{}.tfrec".format(partition) # name of the file

  for x in data:
    image,label = x
    with tf.io.TFRecordWriter(filename) as out_file: # opening the file
      example = to_tfrecord(out_file,
                          image.numpy(), # re-compressed image: already a byte string
                          label.numpy() # defining to write the label
                          )
      out_file.write(example.SerializeToString()) # writing the example
  return [(filename,time.time()-tt0)] # for each partition gives the time
RDD_recompressed.mapPartitionsWithIndex(write_tfrecords_spark).collect() # writing tfrecords of each partition in the bucket
# Out:
# [('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-0.tfrec',
#   28.79013681411743),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-1.tfrec',
#   23.03329110145569)]

# %% [markdown]
# ### 1b)	Testing (3%)
#
# i) Read from the TFRecord Dataset, using `load_data` and `display_9_images_from_dataset` to test.

# %%
def read_tfrecord(example):
    features = {
        "image": tf.io.FixedLenFeature([], tf.string),  # tf.string = bytestring (not text string)
        "class": tf.io.FixedLenFeature([], tf.int64) #,   # shape [] means scalar
    }
    # decode the TFRecord
    example = tf.io.parse_single_example(example, features)
    image = tf.image.decode_jpeg(example['image'], channels=3)
    image = tf.reshape(image, [*TARGET_SIZE, 3])    
    class_num = example['class']
    return image, class_num 

def load_dataset(filenames):
    # read from TFRecords. For optimal performance, read from multiple    
    # TFRecord files at once and set the option experimental_deterministic = False
    # to allow order-altering optimizations.
    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = False

    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.with_options(option_no_order)
    dataset = dataset.map(read_tfrecord)
    return dataset

print(GCS_OUTPUT)    
filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
datasetTfrec = load_dataset(filenames)
display_9_images_from_dataset(datasetTfrec)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#### adding partitions
GCS_PATTERN_tfrec= 'gs://flowers-public/tfrecords-jpeg-192x192-2/*' # gets all of the tfrecord patterns
filenames=tf.io.gfile.glob(GCS_PATTERN_tfrec) # 'tf.io.gfile.glob' gets the patterns and gives the file names
print(filenames[0]) # printing the first filename
RDD=sc.parallelize(filenames).repartition(PARTITIONS)# TASK 1d # creating a RDD of filenames # partitioning filenames because partitioning tfrecords was giving error because of version(tfrecords can not be hashed)
RDD1=RDD.flatMap(load_dataset) # mapping filenames to image and label
# RDD1.first()
RDD_resized=RDD1.map(resize_and_crop_2) # resizing the images 
RDD_resized_recompressed=RDD_resized.map(recompress_2) # compressing the images
# RDD_sample=RDD_resized.sample(False,0.02) # getting a sample from resized images, 'False' so that samples are unique
# display_9_images_from_dataset(RDD_sample.take(10)) # displaying the samples
#RDD_samplep=RDD_resized_recompressed.partitionBy(PARTITIONS) # partitioning the samples to 16 partitions 
RDD_ResRec_sampled=RDD_resized_recompressed.sample(False,0.02) # getting sample from resized and compressed images
# RDD_ResRec_sampled.mapPartitionsWithIndex(lambda i,x: [(i,len(tuple(x)))]).collect() # testing the length of each partition
RDD_ResRec_sampled.mapPartitionsWithIndex(write_tfrecords_spark).collect() # writing tfrecords of each partition in the bucket
# Out:
# gs://flowers-public/tfrecords-jpeg-192x192-2/flowers00-230.tfrec
# [('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-0.tfrec',
#   7.367134094238281e-05),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-1.tfrec',
#   0.00010824203491210938),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-2.tfrec',
#   7.176399230957031e-05),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-3.tfrec',
#   8.797645568847656e-05),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-4.tfrec',
#   69.16763043403625),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-5.tfrec',
#   8.845329284667969e-05),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-6.tfrec',
#   9.5367431640625e-05),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-7.tfrec',
#   0.00010275840759277344),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-8.tfrec',
#   0.00010442733764648438),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-9.tfrec',
#   0.00010323524475097656),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-10.tfrec',
#   6.842613220214844e-05),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-11.tfrec',
#   7.748603820800781e-05),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-12.tfrec',
#   57.91657876968384),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-13.tfrec',
#   7.677078247070312e-05),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-14.tfrec',
#   0.0001010894775390625),
#  ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-15.tfrec',
#   7.295608520507812e-05)]

# %% [markdown]
# ii) Write your code above into a file using the *cell magic* `%%writefile spark_write_tfrec.py` at the beginning of the file. Then, run the file  locally in Spark.

# %%
# writing our codes in a file so that we can run in in cloud later
# %%writefile spark_write_tfrec.py 
import os, sys, math
import numpy as np
import time
import datetime
import string
import random
import pyspark
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
import pickle
PROJECT = 'big-data-adcy439'
BUCKET = 'gs://{}-storage'.format(PROJECT)
 
CLASSES = [b'daisy', b'dandelion', b'roses', b'sunflowers', b'tulips']
  # functions for writing TFRecord entries
# Feature values are always stored as lists, a single data element will be a list of size 1
def _bytestring_feature(list_of_bytestrings):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=list_of_bytestrings))

def _int_feature(list_of_ints): # int64
    return tf.train.Feature(int64_list=tf.train.Int64List(value=list_of_ints))  

def to_tfrecord(tfrec_filewriter, img_bytes, label): # Create tf data records 
    class_num = np.argmax(np.array(CLASSES)==label) # 'roses' => 2 (order defined in CLASSES)
    one_hot_class = np.eye(len(CLASSES))[class_num]     # [0, 0, 1, 0, 0] for class #2, roses
    feature = {
        "image": _bytestring_feature([img_bytes]), # one image in the list
        "class": _int_feature([class_num]) #,      # one class in the list
    }
    return tf.train.Example(features=tf.train.Features(feature=feature))



def dataset_to_numpy_util(dataset, N):
    dataset = dataset.batch(N)
    for images, labels in dataset:
        numpy_images = images.numpy()
        numpy_labels = labels.numpy()
        break;
    return numpy_images, numpy_labels

def title_from_label_and_target(label, correct_label):
  correct = (label == correct_label)
  return "{} [{}{}{}]".format(CLASSES[label], str(correct), ', shoud be ' if not correct else '',
                              CLASSES[correct_label] if not correct else ''), correct


def decode_jpeg_and_label(filepath):
    # extracts the image data and creates a class label, based on the filepath 
    bits = tf.io.read_file(filepath)
    image = tf.image.decode_jpeg(bits)
    # parse flower name from containing directory
    label = tf.strings.split(tf.expand_dims(filepath, axis=-1), sep='/')
    label2 = label.values[-2]
    return image, label2

def resize_and_crop_image(image, label):
    # Resizes and cropd using "fill" algorithm:
    # always make sure the resulting image is cut out from the source image 
    # so that it fills the TARGET_SIZE entirely with no black bars 
    # and a preserved aspect ratio.
    w = tf.shape(image)[0]
    h = tf.shape(image)[1]
    tw = TARGET_SIZE[1]
    th = TARGET_SIZE[0]
    resize_crit = (w * th) / (h * tw)
    image = tf.cond(resize_crit < 1,
                    lambda: tf.image.resize(image, [w*tw/w, h*tw/w]), # if true
                    lambda: tf.image.resize(image, [w*th/h, h*th/h])  # if false
                    )
    nw = tf.shape(image)[0]
    nh = tf.shape(image)[1]
    image = tf.image.crop_to_bounding_box(image, (nw - tw) // 2, (nh - th) // 2, tw, th)
    return image, label

def recompress_image(image, label):
    # this reduces the amount of data, but takes some time
    image = tf.cast(image, tf.uint8)
    image = tf.image.encode_jpeg(image, optimize_size=True, chroma_downsampling=False)
    return image, label
    # GCS_OUTPUT = 'gs://flowers-public/tfrecords-jpeg-192x192-2/' 
# remove the line above to use your own files that you generated above

def read_tfrecord(example):
    features = {
        "image": tf.io.FixedLenFeature([], tf.string),  # tf.string = bytestring (not text string)
        "class": tf.io.FixedLenFeature([], tf.int64) #,   # shape [] means scalar
    }
    # decode the TFRecord
    example = tf.io.parse_single_example(example, features)
    image = tf.image.decode_jpeg(example['image'], channels=3)
    image = tf.reshape(image, [*TARGET_SIZE, 3])    
    class_num = example['class']
    return image, class_num 

def load_dataset(filenames):
    # read from TFRecords. For optimal performance, read from multiple    
    # TFRecord files at once and set the option experimental_deterministic = False
    # to allow order-altering optimizations.
    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = False

    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.with_options(option_no_order)
    dataset = dataset.map(read_tfrecord)
    return dataset

    
#filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
#datasetTfrec = load_dataset(filenames)

def resize_and_crop_2 (x):   
  image,label=x
  image,label=resize_and_crop_image(image,label) # creating a tuple of image and label
  return (image,label) # returning a tuple of image and label

def recompress_2 (y):
  image,label=y
  image,label=recompress_image(image,label) # creating a tuple of image and label
  return(image,label) # returning a tuple of image and label
GCS_PATTERN = 'gs://flowers-public/*/*.jpg' # glob  pattern for input files
TARGET_SIZE = [192, 192] # target resolution for the images
sc = pyspark.SparkContext.getOrCreate()

GCS_PATTERN_RI= GCS_PATTERN # gets the pattern
filenames=tf.io.gfile.glob(GCS_PATTERN_RI) # 'tf.io.gfile.glob' gets the pattern and gives the raw image addresses
print(filenames[0]) # printing the first filename
RDD=sc.parallelize(filenames) # creating a RDD of filenames

# we do not use the sample rdd here

RDD_decoded=RDD.map(decode_jpeg_and_label) # mapping filenames to image and label 
RDD_resized=RDD_decoded.map(resize_and_crop_2) # resizing the images 
RDD_recompressed=RDD_resized.map(recompress_2) # compressing the images

GCS_OUTPUT = BUCKET + '/tfrecords-jpeg-192x192-2-test/flowers' 


def write_tfrecords_spark(partition, data): 
  tt0 = time.time() # for getting the time
  filename = GCS_OUTPUT + '/tfrecords-test/flowers' + "-spark-{}.tfrec".format(partition) # name of the file

  for x in data:
    image,label = x
    with tf.io.TFRecordWriter(filename) as out_file: # opening the file
      example = to_tfrecord(out_file,
                          image.numpy(), # re-compressed image: already a byte string
                          label.numpy() # defining to write the label
                          )
      out_file.write(example.SerializeToString()) # writing the example
  return [(filename,time.time()-tt0)] # for each partition gives the time
output=RDD_recompressed.mapPartitionsWithIndex(write_tfrecords_spark).collect() # writing tfrecords of each partition in the bucket

print(output)
# Out:
# Overwriting spark_write_tfrec.py

# %%
# !cat spark_write_tfrec.py
# !pwd # checking
# Out:
# import os, sys, math
# import numpy as np
# import time
# import datetime
# import string
# import random
# import pyspark
# import tensorflow as tf
# print("Tensorflow version " + tf.__version__)
# import pickle
# PROJECT = 'big-data-adcy439'
# BUCKET = 'gs://{}-storage'.format(PROJECT)
#
# CLASSES = [b'daisy', b'dandelion', b'roses', b'sunflowers', b'tulips']
#   # functions for writing TFRecord entries
# # Feature values are always stored as lists, a single data element will be a list of size 1
# def _bytestring_feature(list_of_bytestrings):
#     return tf.train.Feature(bytes_list=tf.train.BytesList(value=list_of_bytestrings))
#
# def _int_feature(list_of_ints): # int64
#     return tf.train.Feature(int64_list=tf.train.Int64List(value=list_of_ints))
#
# def to_tfrecord(tfrec_filewriter, img_bytes, label): # Create tf data records
#     class_num = np.argmax(np.array(CLASSES)==label) # 'roses' => 2 (order defined in CLASSES)
#     one_hot_class = np.eye(len(CLASSES))[class_num]     # [0, 0, 1, 0, 0] for class #2, roses
#     feature = {
#         "image": _bytestring_feature([img_bytes]), # one image in the list
#         "class": _int_feature([class_num]) #,      # one class in the list
#     }
#     return tf.train.Example(features=tf.train.Features(feature=feature))
#
#
#
# def dataset_to_numpy_util(dataset, N):
#     dataset = dataset.batch(N)
#     for images, labels in dataset:
#         numpy_images = images.numpy()
#         numpy_labels = labels.numpy()
#         break;
#     return numpy_images, numpy_labels
#
# def title_from_label_and_target(label, correct_label):
#   correct = (label == correct_label)
#   return "{} [{}{}{}]".format(CLASSES[label], str(correct), ', shoud be ' if not correct else '',
#                               CLASSES[correct_label] if not correct else ''), correct
#
#
# def decode_jpeg_and_label(filepath):
#     # extracts the image data and creates a class label, based on the filepath
#     bits = tf.io.read_file(filepath)
#     image = tf.image.decode_jpeg(bits)
#     # parse flower name from containing directory
#     label = tf.strings.split(tf.expand_dims(filepath, axis=-1), sep='/')
#     label2 = label.values[-2]
#     return image, label2
#
# def resize_and_crop_image(image, label):
#     # Resizes and cropd using "fill" algorithm:
#     # always make sure the resulting image is cut out from the source image
#     # so that it fills the TARGET_SIZE entirely with no black bars
#     # and a preserved aspect ratio.
#     w = tf.shape(image)[0]
#     h = tf.shape(image)[1]
#     tw = TARGET_SIZE[1]
#     th = TARGET_SIZE[0]
#     resize_crit = (w * th) / (h * tw)
#     image = tf.cond(resize_crit < 1,
#                     lambda: tf.image.resize(image, [w*tw/w, h*tw/w]), # if true
#                     lambda: tf.image.resize(image, [w*th/h, h*th/h])  # if false
#                     )
#     nw = tf.shape(image)[0]
#     nh = tf.shape(image)[1]
#     image = tf.image.crop_to_bounding_box(image, (nw - tw) // 2, (nh - th) // 2, tw, th)
#     return image, label
#
# def recompress_image(image, label):
#     # this reduces the amount of data, but takes some time
#     image = tf.cast(image, tf.uint8)
#     image = tf.image.encode_jpeg(image, optimize_size=True, chroma_downsampling=False)
#     return image, label
#     # GCS_OUTPUT = 'gs://flowers-public/tfrecords-jpeg-192x192-2/'
# # remove the line above to use your own files that you generated above
#
# def read_tfrecord(example):
#     features = {
#         "image": tf.io.FixedLenFeature([], tf.string),  # tf.string = bytestring (not text string)
#         "class": tf.io.FixedLenFeature([], tf.int64) #,   # shape [] means scalar
#     }
#     # decode the TFRecord
#     example = tf.io.parse_single_example(example, features)
#     image = tf.image.decode_jpeg(example['image'], channels=3)
#     image = tf.reshape(image, [*TARGET_SIZE, 3])
#     class_num = example['class']
#     return image, class_num
#
# def load_dataset(filenames):
#     # read from TFRecords. For optimal performance, read from multiple
#     # TFRecord files at once and set the option experimental_deterministic = False
#     # to allow order-altering optimizations.
#     option_no_order = tf.data.Options()
#     option_no_order.experimental_deterministic = False
#
#     dataset = tf.data.TFRecordDataset(filenames)
#     dataset = dataset.with_options(option_no_order)
#     dataset = dataset.map(read_tfrecord)
#     return dataset
#
#
# #filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
# #datasetTfrec = load_dataset(filenames)
#
# def resize_and_crop_2 (x):
#   image,label=x
#   image,label=resize_and_crop_image(image,label) # creating a tuple of image and label
#   return (image,label) # returning a tuple of image and label
#
# def recompress_2 (y):
#   image,label=y
#   image,label=recompress_image(image,label) # creating a tuple of image and label
#   return(image,label) # returning a tuple of image and label
# GCS_PATTERN = 'gs://flowers-public/*/*.jpg' # glob  pattern for input files
# TARGET_SIZE = [192, 192] # target resolution for the images
# sc = pyspark.SparkContext.getOrCreate()
#
# GCS_PATTERN_RI= GCS_PATTERN # gets the pattern
# filenames=tf.io.gfile.glob(GCS_PATTERN_RI) # 'tf.io.gfile.glob' gets the pattern and gives the raw image addresses
# print(filenames[0]) # printing the first filename
# RDD=sc.parallelize(filenames) # creating a RDD of filenames
#
# # we do not use the sample rdd here
#
# RDD_decoded=RDD.map(decode_jpeg_and_label) # mapping filenames to image and label
# RDD_resized=RDD_decoded.map(resize_and_crop_2) # resizing the images
# RDD_recompressed=RDD_resized.map(recompress_2) # compressing the images
#
# GCS_OUTPUT = BUCKET + '/tfrecords-jpeg-192x192-2-test/flowers'
#
#
# def write_tfrecords_spark(partition, data):
#   tt0 = time.time() # for getting the time
#   filename = GCS_OUTPUT + '/tfrecords-test/flowers' + "-spark-{}.tfrec".format(partition) # name of the file
#
#   for x in data:
#     image,label = x
#     with tf.io.TFRecordWriter(filename) as out_file: # opening the file
#       example = to_tfrecord(out_file,
#                           image.numpy(), # re-compressed image: already a byte string
#                           label.numpy() # defining to write the label
#                           )
#       out_file.write(example.SerializeToString()) # writing the example
#   return [(filename,time.time()-tt0)] # for each partition gives the time
# output=RDD_recompressed.mapPartitionsWithIndex(write_tfrecords_spark).collect() # writing tfrecords of each partition in the bucket
#
# print(output)
# /root

# %%
# writing our codes in a file so that we can run in in cloud later # this is for 16 partitions
# %%writefile spark_write_tfrec16.py 
import os, sys, math
import numpy as np
import time
import datetime
import string
import random
import pyspark
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
import pickle
#import scipy as sc



  # functions for writing TFRecord entries
# Feature values are always stored as lists, a single data element will be a list of size 1
def _bytestring_feature(list_of_bytestrings):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=list_of_bytestrings))

def _int_feature(list_of_ints): # int64
    return tf.train.Feature(int64_list=tf.train.Int64List(value=list_of_ints))  

def to_tfrecord(tfrec_filewriter, img_bytes, label): # Create tf data records 
    class_num = np.argmax(np.array(CLASSES)==label) # 'roses' => 2 (order defined in CLASSES)
    one_hot_class = np.eye(len(CLASSES))[class_num]     # [0, 0, 1, 0, 0] for class #2, roses
    feature = {
        "image": _bytestring_feature([img_bytes]), # one image in the list
        "class": _int_feature([class_num]) #,      # one class in the list
    }
    return tf.train.Example(features=tf.train.Features(feature=feature))



def dataset_to_numpy_util(dataset, N):
    dataset = dataset.batch(N)
    for images, labels in dataset:
        numpy_images = images.numpy()
        numpy_labels = labels.numpy()
        break;
    return numpy_images, numpy_labels

def title_from_label_and_target(label, correct_label):
  correct = (label == correct_label)
  return "{} [{}{}{}]".format(CLASSES[label], str(correct), ', shoud be ' if not correct else '',
                              CLASSES[correct_label] if not correct else ''), correct


def decode_jpeg_and_label(filepath):
    # extracts the image data and creates a class label, based on the filepath 
    bits = tf.io.read_file(filepath)
    image = tf.image.decode_jpeg(bits)
    # parse flower name from containing directory
    label = tf.strings.split(tf.expand_dims(filepath, axis=-1), sep='/')
    label2 = label.values[-2]
    return image, label2

def resize_and_crop_image(image, label):
    # Resizes and cropd using "fill" algorithm:
    # always make sure the resulting image is cut out from the source image 
    # so that it fills the TARGET_SIZE entirely with no black bars 
    # and a preserved aspect ratio.
    w = tf.shape(image)[0]
    h = tf.shape(image)[1]
    tw = TARGET_SIZE[1]
    th = TARGET_SIZE[0]
    resize_crit = (w * th) / (h * tw)
    image = tf.cond(resize_crit < 1,
                    lambda: tf.image.resize(image, [w*tw/w, h*tw/w]), # if true
                    lambda: tf.image.resize(image, [w*th/h, h*th/h])  # if false
                    )
    nw = tf.shape(image)[0]
    nh = tf.shape(image)[1]
    image = tf.image.crop_to_bounding_box(image, (nw - tw) // 2, (nh - th) // 2, tw, th)
    return image, label

def recompress_image(image, label):
    # this reduces the amount of data, but takes some time
    image = tf.cast(image, tf.uint8)
    image = tf.image.encode_jpeg(image, optimize_size=True, chroma_downsampling=False)
    return image, label
    # GCS_OUTPUT = 'gs://flowers-public/tfrecords-jpeg-192x192-2/' 
# remove the line above to use your own files that you generated above

def read_tfrecord(example):
    features = {
        "image": tf.io.FixedLenFeature([], tf.string),  # tf.string = bytestring (not text string)
        "class": tf.io.FixedLenFeature([], tf.int64) #,   # shape [] means scalar
    }
    # decode the TFRecord
    example = tf.io.parse_single_example(example, features)
    image = tf.image.decode_jpeg(example['image'], channels=3)
    image = tf.reshape(image, [*TARGET_SIZE, 3])    
    class_num = example['class']
    return image, class_num 

def load_dataset(filenames):
    # read from TFRecords. For optimal performance, read from multiple    
    # TFRecord files at once and set the option experimental_deterministic = False
    # to allow order-altering optimizations.
    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = False

    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.with_options(option_no_order)
    dataset = dataset.map(read_tfrecord)
    return dataset

    
#filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
#datasetTfrec = load_dataset(filenames)

def resize_and_crop_2 (x):   
  image,label=x
  image,label=resize_and_crop_image(image,label) # creating a tuple of image and label
  return (image,label) # returning a tuple of image and label

def recompress_2 (y):
  image,label=y
  image,label=recompress_image(image,label) # creating a tuple of image and label
  return(image,label) # returning a tuple of image and label

def write_tfrecords_spark(partition, data): 
  tt0 = time.time() # for getting the time

  for x in data:
    image,label = x
    filename = BUCKET + '/tfrecords-test/flowers' + "-spark-{}.tfrec".format(partition) # name of the file
    with tf.io.TFRecordWriter(filename) as out_file: # opening the file
      example = to_tfrecord(out_file,
                          image.numpy(), # re-compressed image: already a byte string
                          label.numpy() # defining to write the label
                          )
      out_file.write(example.SerializeToString()) # writing the example
  return [(partition,time.time()-tt0)] # for each partition gives the time
  
PROJECT = 'big-data-adcy439'
BUCKET = 'gs://{}-storage'.format(PROJECT)

GCS_PATTERN = 'gs://flowers-public/*/*.jpg' # glob  pattern for input files
PARTITIONS = 16 # no of partitions we will use later 
TARGET_SIZE = [192, 192] # target resolution for the images
CLASSES = [b'daisy', b'dandelion', b'roses', b'sunflowers', b'tulips']
    # labels for the data 

sc = pyspark.SparkContext.getOrCreate()
#### adding partitions
GCS_PATTERN_tfrec= 'gs://flowers-public/tfrecords-jpeg-192x192-2/*' # gets all of the tfrecord patterns
filenames=tf.io.gfile.glob(GCS_PATTERN_tfrec) # 'tf.io.gfile.glob' gets the patterns and gives the file names
print(filenames[0]) # printing the first filename
RDD=sc.parallelize(filenames).repartition(PARTITIONS)# TASK 1d # creating a RDD of filenames # partitioning filenames because partitioning tfrecords was giving error because of version(tfrecords can not be hashed)
RDD1=RDD.flatMap(load_dataset) # mapping filenames to image and label
# RDD1.first()
RDD_resized=RDD1.map(resize_and_crop_2) # resizing the images 
RDD_resized_recompressed=RDD_resized.map(recompress_2) # compressing the images
# RDD_sample=RDD_resized.sample(False,0.02) # getting a sample from resized images, 'False' so that samples are unique
# display_9_images_from_dataset(RDD_sample.take(10)) # displaying the samples
#RDD_samplep=RDD_resized_recompressed.partitionBy(PARTITIONS) # partitioning the samples to 16 partitions 
RDD_ResRec_sampled=RDD_resized_recompressed.sample(False,0.02) # getting sample from resized and compressed images
# RDD_ResRec_sampled.mapPartitionsWithIndex(lambda i,x: [(i,len(tuple(x)))]).collect() # testing the length of each partition
output=RDD_ResRec_sampled.mapPartitionsWithIndex(write_tfrecords_spark).collect() # writing tfrecords of each partition in the bucket
print(output)
# Out:
# Overwriting spark_write_tfrec16.py

# %% [markdown]
# ### 1c) Set up a cluster and run the script. (6%)
#
# Following the example from the labs, set up a cluster to run PySpark jobs in the cloud. You need to set up so that TensorFlow is installed on all nodes in the cluster.

# %% [markdown]
# #### i) Single machine cluster
# Set up a cluster with a single machine using the maximal SSD size (100) and 8 vCPUs.
#
# Enable **package installation** by passing a flag `--initialization-actions` with argument `gs://goog-dataproc-initialization-actions-$REGION/python/pip-install.sh` (this is a public script that will read metadata to determine which packages to install).
# Then, the **packages are specified** by providing a `--metadata` flag with the argument `PIP_PACKAGES=tensorflow==2.4.0`.
#
# When the cluster is running, run your script to check that it works and keep the output cell output. (3%)

# %%
### CODING TASK ###
# some parts of this code is extracted from lab 4b
# !gcloud dataproc clusters create $CLUSTER \
    --bucket $PROJECT-storage \
    --image-version 1.4-ubuntu18 --single-node \
    --master-machine-type n1-standard-8 \
    --master-boot-disk-type pd-ssd --master-boot-disk-size 100\
    --initialization-actions gs://goog-dataproc-initialization-actions-$REGION/python/pip-install.sh \
    --metadata PIP_PACKAGES=tensorflow==2.4.0
# Out:
# Waiting on operation [projects/big-data-adcy439/regions/us-central1/operations/b4e8fd66-b6fb-3264-8bf1-2553ee1e5a1f].
#
# WARNING: Don't create production clusters that reference initialization actions located in the gs://goog-dataproc-initialization-actions-REGION public buckets. These scripts are provided as reference implementations, and they are synchronized with ongoing GitHub repository changes—a new version of a initialization action in public buckets may break your cluster creation. Instead, copy the following initialization actions from public buckets into your bucket : gs://goog-dataproc-initialization-actions-us-central1/python/pip-install.sh
# WARNING: Failed to validate permissions required for default service account: '175564710579-compute@developer.gserviceaccount.com'. Cluster creation could still be successful if required permissions have been granted to the respective service accounts as mentioned in the document https://cloud.google.com/dataproc/docs/concepts/configuring-clusters/service-accounts#dataproc_service_accounts_2. This could be due to Cloud Resource Manager API hasn't been enabled in your project '175564710579' before or it is disabled. Enable it by visiting 'https://console.developers.google.com/apis/api/cloudresourcemanager.googleapis.com/overview?project=175564710579'.
# Created [https://dataproc.googleapis.com/v1/projects/big-data-adcy439/regions/us-central1/clusters/big-data-adcy439-cluster] Cluster placed in zone [us-central1-b].

# %% [markdown]
# Run the script in the cloud and test the output.

# %%
### CODING TASK ###
# run the file in the cluster (with two partitions)
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_write_tfrec.py
# Out:
# Job [e561861e956141cf984efbb8f29fc9ca] submitted.
# Waiting for job output...
# 2023-05-05 21:10:01.641025: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 21:10:01.641067: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.4.0
# 23/05/05 21:10:04 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 21:10:04 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 21:10:04 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 21:10:04 INFO org.spark_project.jetty.util.log: Logging initialized @5015ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 21:10:04 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 21:10:04 INFO org.spark_project.jetty.server.Server: Started @5117ms
# 23/05/05 21:10:04 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@3a6d2388{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 21:10:04 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 21:10:05 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-cluster-m/10.128.0.57:8032
# 23/05/05 21:10:05 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-cluster-m/10.128.0.57:10200
# 23/05/05 21:10:08 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683320889768_0001
# gs://flowers-public/daisy/100080576_f52e8ee070_n.jpg
# 23/05/05 21:10:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 0 contains a task of very large size (134 KB). The maximum recommended task size is 100 KB.
# [('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-0.tfrec', 1543.2494084835052), ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-1.tfrec', 1244.9439005851746)]
# 23/05/05 21:36:02 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@3a6d2388{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [e561861e956141cf984efbb8f29fc9ca] finished successfully.
# done: true
# driverControlFilesUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/6f185e74-6264-4245-bf98-c4020a42766f/jobs/e561861e956141cf984efbb8f29fc9ca/
# driverOutputResourceUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/6f185e74-6264-4245-bf98-c4020a42766f/jobs/e561861e956141cf984efbb8f29fc9ca/driveroutput
# jobUuid: d1591ba2-1ae3-36e3-a67f-313d54e4f4f4
# placement:
#   clusterName: big-data-adcy439-cluster
#   clusterUuid: 6f185e74-6264-4245-bf98-c4020a42766f
# pysparkJob:
#   mainPythonFileUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/6f185e74-6264-4245-bf98-c4020a42766f/jobs/e561861e956141cf984efbb8f29fc9ca/staging/spark_write_tfrec.py
# reference:
#   jobId: e561861e956141cf984efbb8f29fc9ca
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-05-05T21:36:05.478195Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-05-05T21:09:58.158925Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-05-05T21:09:58.191387Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-05-05T21:09:58.502235Z'
# yarnApplications:
# - name: spark_write_tfrec.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-cluster-m:8088/proxy/application_1683320889768_0001/

# %%
### CODING TASK ###
# run the file in the cluster (with 16 partitions)
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_write_tfrec16.py
# Out:
# Job [d117c5ced4354b1d9a1472b1ebaca8a3] submitted.
# Waiting for job output...
# 2023-05-05 21:40:17.695688: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 21:40:17.695751: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.4.0
# 23/05/05 21:40:20 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 21:40:20 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 21:40:20 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 21:40:20 INFO org.spark_project.jetty.util.log: Logging initialized @4612ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 21:40:20 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 21:40:20 INFO org.spark_project.jetty.server.Server: Started @4720ms
# 23/05/05 21:40:20 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@30a43356{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 21:40:20 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 21:40:21 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-cluster-m/10.128.0.57:8032
# 23/05/05 21:40:21 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-cluster-m/10.128.0.57:10200
# 23/05/05 21:40:23 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683320889768_0002
# gs://flowers-public/tfrecords-jpeg-192x192-2/flowers00-230.tfrec
# [(0, 0.0001304149627685547), (1, 7.62939453125e-05), (2, 5.316734313964844e-05), (3, 7.867813110351562e-05), (4, 32.44452524185181), (5, 9.322166442871094e-05), (6, 6.222724914550781e-05), (7, 7.82012939453125e-05), (8, 5.5789947509765625e-05), (9, 5.507469177246094e-05), (10, 7.414817810058594e-05), (11, 6.604194641113281e-05), (12, 25.16409158706665), (13, 8.487701416015625e-05), (14, 5.412101745605469e-05), (15, 5.412101745605469e-05)]
# 23/05/05 21:41:06 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@30a43356{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [d117c5ced4354b1d9a1472b1ebaca8a3] finished successfully.
# done: true
# driverControlFilesUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/6f185e74-6264-4245-bf98-c4020a42766f/jobs/d117c5ced4354b1d9a1472b1ebaca8a3/
# driverOutputResourceUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/6f185e74-6264-4245-bf98-c4020a42766f/jobs/d117c5ced4354b1d9a1472b1ebaca8a3/driveroutput
# jobUuid: d65da646-e262-3b68-b75f-456174ec9be7
# placement:
#   clusterName: big-data-adcy439-cluster
#   clusterUuid: 6f185e74-6264-4245-bf98-c4020a42766f
# pysparkJob:
#   mainPythonFileUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/6f185e74-6264-4245-bf98-c4020a42766f/jobs/d117c5ced4354b1d9a1472b1ebaca8a3/staging/spark_write_tfrec16.py
# reference:
#   jobId: d117c5ced4354b1d9a1472b1ebaca8a3
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-05-05T21:41:10.649556Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-05-05T21:40:14.457941Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-05-05T21:40:14.495447Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-05-05T21:40:14.755849Z'
# yarnApplications:
# - name: spark_write_tfrec16.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-cluster-m:8088/proxy/application_1683320889768_0002/

# %% [markdown]
# In the free credit tier on Google Cloud, there are normally the following **restrictions** on compute machines:
# - max 100GB of *SSD persistent disk*
# - max 2000GB of *standard persistent disk*
# - max 8 *vCPU*s
# - no GPUs
#
# See [here](https://cloud.google.com/free/docs/gcp-free-tier#free-trial) for details
# The **disks are virtual** disks, where **I/O speed is limited in proportion to the size**, so we should allocate them evenly.
# This has mainly an effect on the **time the cluster needs to start**, as we are reading the data mainly from the bucket and we are not writing much to disk at all.

# %% [markdown]
# #### ii) Maximal cluster
# Use the **largest possible cluster** within these constraints, i.e. **1 master and 7 worker nodes**.
# Each of them with 1 (virtual) CPU.
# The master should get the full *SSD* capacity and the 7 worker nodes should get equal shares of the *standard* disk capacity to maximise throughput.
#
# Once the cluster is running, test your script. (3%)

# %%
### CODING TASK ###

# creating the cluster
size=2000//7
CLUSTER = '{}-maximal-cluster-7-workers'.format(PROJECT)
# !gcloud dataproc clusters create $CLUSTER \
--bucket $PROJECT-storage \
--num-workers=7 \
--metadata PIP_PACKAGES="tensorflow numpy"\
--master-machine-type=n1-standard-1\
--worker-machine-type=n1-standard-1 \
--worker-boot-disk-type pd-standard --worker-boot-disk-size $size \
--master-boot-disk-type pd-ssd --master-boot-disk-size 100 \
--image-version=1.4-ubuntu18 \
--initialization-actions gs://goog-dataproc-initialization-actions-$REGION/python/pip-install.sh \
--metadata PIP_PACKAGES=tensorflow==2.4.0
# Out:
# Waiting on operation [projects/big-data-adcy439/regions/us-central1/operations/bd0dec07-6ea5-3c2f-8581-183c4719c0b1].
#
# WARNING: Creating clusters using the n1-standard-1 machine type is not recommended. Consider using a machine type with higher memory.
# WARNING: Don't create production clusters that reference initialization actions located in the gs://goog-dataproc-initialization-actions-REGION public buckets. These scripts are provided as reference implementations, and they are synchronized with ongoing GitHub repository changes—a new version of a initialization action in public buckets may break your cluster creation. Instead, copy the following initialization actions from public buckets into your bucket : gs://goog-dataproc-initialization-actions-us-central1/python/pip-install.sh
# WARNING: Failed to validate permissions required for default service account: '175564710579-compute@developer.gserviceaccount.com'. Cluster creation could still be successful if required permissions have been granted to the respective service accounts as mentioned in the document https://cloud.google.com/dataproc/docs/concepts/configuring-clusters/service-accounts#dataproc_service_accounts_2. This could be due to Cloud Resource Manager API hasn't been enabled in your project '175564710579' before or it is disabled. Enable it by visiting 'https://console.developers.google.com/apis/api/cloudresourcemanager.googleapis.com/overview?project=175564710579'.
# WARNING: For PD-Standard without local SSDs, we strongly recommend provisioning 1TB or larger to ensure consistently high I/O performance. See https://cloud.google.com/compute/docs/disks/performance for information on disk I/O performance.
# Created [https://dataproc.googleapis.com/v1/projects/big-data-adcy439/regions/us-central1/clusters/big-data-adcy439-maximal-cluster-7-workers] Cluster placed in zone [us-central1-a].

# %%
# running the file in the cluster ( with two partitions)
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_write_tfrec.py
# Out:
# Job [68cb362a687b4461ad29acdd4bba1c28] submitted.
# Waiting for job output...
# 2023-05-05 21:57:51.058909: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 21:57:51.059090: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.4.0
# 23/05/05 21:57:55 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 21:57:55 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 21:57:55 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 21:57:55 INFO org.spark_project.jetty.util.log: Logging initialized @8875ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 21:57:55 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 21:57:55 INFO org.spark_project.jetty.server.Server: Started @9197ms
# 23/05/05 21:57:55 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@586fc5d{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 21:57:56 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 21:57:58 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-maximal-cluster-7-workers-m/10.128.0.61:8032
# 23/05/05 21:57:58 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-maximal-cluster-7-workers-m/10.128.0.61:10200
# 23/05/05 21:58:02 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683323696540_0001
# gs://flowers-public/daisy/100080576_f52e8ee070_n.jpg
# 23/05/05 21:58:23 WARN org.apache.spark.scheduler.TaskSetManager: Stage 0 contains a task of very large size (134 KB). The maximum recommended task size is 100 KB.
# [('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-0.tfrec', 863.7255845069885), ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-1.tfrec', 726.3004856109619)]
# 23/05/05 22:12:53 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@586fc5d{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [68cb362a687b4461ad29acdd4bba1c28] finished successfully.
# done: true
# driverControlFilesUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4bce9357-8495-445c-bc6e-0d687e024014/jobs/68cb362a687b4461ad29acdd4bba1c28/
# driverOutputResourceUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4bce9357-8495-445c-bc6e-0d687e024014/jobs/68cb362a687b4461ad29acdd4bba1c28/driveroutput
# jobUuid: 67fe7369-3518-3edc-961f-8cee7d40de70
# placement:
#   clusterName: big-data-adcy439-maximal-cluster-7-workers
#   clusterUuid: 4bce9357-8495-445c-bc6e-0d687e024014
# pysparkJob:
#   mainPythonFileUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4bce9357-8495-445c-bc6e-0d687e024014/jobs/68cb362a687b4461ad29acdd4bba1c28/staging/spark_write_tfrec.py
# reference:
#   jobId: 68cb362a687b4461ad29acdd4bba1c28
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-05-05T22:12:58.032479Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-05-05T21:57:43.553460Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-05-05T21:57:43.604930Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-05-05T21:57:44.000206Z'
# yarnApplications:
# - name: spark_write_tfrec.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-maximal-cluster-7-workers-m:8088/proxy/application_1683323696540_0001/

# %%
### CODING TASK ###
# testing 
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER \
#  spark_write_tfrec.py
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_write_tfrec16.py
# Out:
# Job [1112162cb7724c199283b734c691bd96] submitted.
# Waiting for job output...
# 2023-05-05 22:25:36.109305: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 22:25:36.109504: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.4.0
# 23/05/05 22:25:39 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 22:25:39 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 22:25:39 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 22:25:39 INFO org.spark_project.jetty.util.log: Logging initialized @7225ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 22:25:39 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 22:25:39 INFO org.spark_project.jetty.server.Server: Started @7421ms
# 23/05/05 22:25:40 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@21d967bc{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 22:25:40 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 22:25:42 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-maximal-cluster-7-workers-m/10.128.0.61:8032
# 23/05/05 22:25:42 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-maximal-cluster-7-workers-m/10.128.0.61:10200
# 23/05/05 22:25:45 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683323696540_0002
# gs://flowers-public/tfrecords-jpeg-192x192-2/flowers00-230.tfrec
# [(0, 7.390975952148438e-05), (1, 9.560585021972656e-05), (2, 7.915496826171875e-05), (3, 7.724761962890625e-05), (4, 21.519832134246826), (5, 5.2928924560546875e-05), (6, 5.3882598876953125e-05), (7, 4.553794860839844e-05), (8, 6.508827209472656e-05), (9, 5.269050598144531e-05), (10, 6.246566772460938e-05), (11, 4.553794860839844e-05), (12, 20.666279315948486), (13, 4.5299530029296875e-05), (14, 6.341934204101562e-05), (15, 6.67572021484375e-05)]
# 23/05/05 22:26:32 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@21d967bc{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [1112162cb7724c199283b734c691bd96] finished successfully.
# done: true
# driverControlFilesUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4bce9357-8495-445c-bc6e-0d687e024014/jobs/1112162cb7724c199283b734c691bd96/
# driverOutputResourceUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4bce9357-8495-445c-bc6e-0d687e024014/jobs/1112162cb7724c199283b734c691bd96/driveroutput
# jobUuid: 61776b42-5436-30be-af54-a1b3e80494ca
# placement:
#   clusterName: big-data-adcy439-maximal-cluster-7-workers
#   clusterUuid: 4bce9357-8495-445c-bc6e-0d687e024014
# pysparkJob:
#   mainPythonFileUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4bce9357-8495-445c-bc6e-0d687e024014/jobs/1112162cb7724c199283b734c691bd96/staging/spark_write_tfrec16.py
# reference:
#   jobId: 1112162cb7724c199283b734c691bd96
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-05-05T22:26:33.547026Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-05-05T22:25:31.361976Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-05-05T22:25:31.404797Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-05-05T22:25:31.646650Z'
# yarnApplications:
# - name: spark_write_tfrec16.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-maximal-cluster-7-workers-m:8088/proxy/application_1683323696540_0002/

# %% [markdown]
# ## 1d)	Optimisation, experiments, and discussion (17%)
#
# i) Improve parallelisation
#
# If you implemented a straightfoward version, you will
# **probably** observe that **all the computation** is done on only **two nodes**.
# This can be adressed by using the **second parameter** in the initial call to **parallelize**.
# Make the **suitable change** in the code you have written above and mark it up in comments as `### TASK 1d ###`.
#
# Demonstrate the difference in cluster utilisation before and after the change based on different parameter values with **screenshots from Google Cloud** and measure the **difference in the processing time**. (6%)
#
# ii) Experiment with cluster configurations.
#
# In addition to the experiments above (using 8 VMs),test your program with 4 machines with double the resources each (2 vCPUs, memory, disk) and 1 machine with eightfold resources.
# Discuss the results in terms of disk I/O and network bandwidth allocation in the cloud. (7%)
#
# iii) Explain the difference between this use of Spark and most standard applications like e.g. in our labs in terms of where the data is stored. What kind of parallelisation approach is used here? (4%)
#
# Write the code below and your answers in the report.

# %%
#1)d)ii :
# creating the cluster ( trying with different cluster configurations )
size=2000//7
CLUSTER = '{}-maximal-cluster-4-workers'.format(PROJECT)
# !gcloud dataproc clusters create $CLUSTER \
--bucket $PROJECT-storage \
--num-workers=4 \
--metadata PIP_PACKAGES="tensorflow numpy"\
--master-machine-type=n1-standard-8 \
--worker-machine-type=n1-standard-2 \
--worker-boot-disk-type pd-standard --worker-boot-disk-size $size \
--master-boot-disk-type pd-ssd --master-boot-disk-size 300 \
--image-version=1.4-ubuntu18 \
--initialization-actions gs://goog-dataproc-initialization-actions-$REGION/python/pip-install.sh \
--metadata PIP_PACKAGES=tensorflow==2.4.0
# Out:
# Waiting on operation [projects/big-data-adcy439/regions/us-central1/operations/278cd6fb-7977-3dcc-a92b-9aab2ee77096].
#
# WARNING: Don't create production clusters that reference initialization actions located in the gs://goog-dataproc-initialization-actions-REGION public buckets. These scripts are provided as reference implementations, and they are synchronized with ongoing GitHub repository changes—a new version of a initialization action in public buckets may break your cluster creation. Instead, copy the following initialization actions from public buckets into your bucket : gs://goog-dataproc-initialization-actions-us-central1/python/pip-install.sh
# WARNING: Failed to validate permissions required for default service account: '175564710579-compute@developer.gserviceaccount.com'. Cluster creation could still be successful if required permissions have been granted to the respective service accounts as mentioned in the document https://cloud.google.com/dataproc/docs/concepts/configuring-clusters/service-accounts#dataproc_service_accounts_2. This could be due to Cloud Resource Manager API hasn't been enabled in your project '175564710579' before or it is disabled. Enable it by visiting 'https://console.developers.google.com/apis/api/cloudresourcemanager.googleapis.com/overview?project=175564710579'.
# WARNING: For PD-Standard without local SSDs, we strongly recommend provisioning 1TB or larger to ensure consistently high I/O performance. See https://cloud.google.com/compute/docs/disks/performance for information on disk I/O performance.
# Created [https://dataproc.googleapis.com/v1/projects/big-data-adcy439/regions/us-central1/clusters/big-data-adcy439-maximal-cluster-4-workers] Cluster placed in zone [us-central1-a].

# %%
# running the file in the cluster ( with two partitions)
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_write_tfrec.py
# Out:
# Job [a76db58315d44197b753b3718d5d6179] submitted.
# Waiting for job output...
# 2023-05-05 00:12:50.590872: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 00:12:50.590916: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.4.0
# 23/05/05 00:12:53 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 00:12:53 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 00:12:53 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 00:12:53 INFO org.spark_project.jetty.util.log: Logging initialized @5573ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 00:12:53 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 00:12:53 INFO org.spark_project.jetty.server.Server: Started @5679ms
# 23/05/05 00:12:53 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@204d89e4{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 00:12:53 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 00:12:54 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-maximal-cluster-4-workers-m/10.128.0.48:8032
# 23/05/05 00:12:54 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-maximal-cluster-4-workers-m/10.128.0.48:10200
# 23/05/05 00:12:57 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683245425808_0001
# gs://flowers-public/daisy/100080576_f52e8ee070_n.jpg
# 23/05/05 00:13:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 0 contains a task of very large size (134 KB). The maximum recommended task size is 100 KB.
# [('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-0.tfrec', 858.6610095500946), ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-1.tfrec', 672.3948774337769)]
# 23/05/05 00:27:36 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@204d89e4{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [a76db58315d44197b753b3718d5d6179] finished successfully.
# done: true
# driverControlFilesUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/e8d4a3fa-f3ec-4857-bcd2-58386584782b/jobs/a76db58315d44197b753b3718d5d6179/
# driverOutputResourceUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/e8d4a3fa-f3ec-4857-bcd2-58386584782b/jobs/a76db58315d44197b753b3718d5d6179/driveroutput
# jobUuid: 2bde93b6-ce48-310e-8d06-d28ff64adae6
# placement:
#   clusterName: big-data-adcy439-maximal-cluster-4-workers
#   clusterUuid: e8d4a3fa-f3ec-4857-bcd2-58386584782b
# pysparkJob:
#   mainPythonFileUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/e8d4a3fa-f3ec-4857-bcd2-58386584782b/jobs/a76db58315d44197b753b3718d5d6179/staging/spark_write_tfrec.py
# reference:
#   jobId: a76db58315d44197b753b3718d5d6179
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-05-05T00:27:42.089334Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-05-05T00:12:46.107029Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-05-05T00:12:46.150953Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-05-05T00:12:46.446674Z'
# yarnApplications:
# - name: spark_write_tfrec.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-maximal-cluster-4-workers-m:8088/proxy/application_1683245425808_0001/

# %%
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_write_tfrec16.py
# Out:
# Job [5adf4e4d54a24dc79eed7eb035366f8a] submitted.
# Waiting for job output...
# 2023-05-05 00:33:08.967519: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 00:33:08.967561: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.4.0
# 23/05/05 00:33:11 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 00:33:11 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 00:33:11 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 00:33:11 INFO org.spark_project.jetty.util.log: Logging initialized @4486ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 00:33:11 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 00:33:11 INFO org.spark_project.jetty.server.Server: Started @4598ms
# 23/05/05 00:33:11 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@7655c0b4{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 00:33:11 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 00:33:12 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-maximal-cluster-4-workers-m/10.128.0.48:8032
# 23/05/05 00:33:12 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-maximal-cluster-4-workers-m/10.128.0.48:10200
# 23/05/05 00:33:14 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683245425808_0002
# gs://flowers-public/tfrecords-jpeg-192x192-2/flowers00-230.tfrec
# [(0, 8.416175842285156e-05), (1, 9.775161743164062e-05), (2, 7.200241088867188e-05), (3, 7.081031799316406e-05), (4, 21.376699924468994), (5, 6.508827209472656e-05), (6, 5.793571472167969e-05), (7, 5.555152893066406e-05), (8, 4.792213439941406e-05), (9, 7.128715515136719e-05), (10, 5.14984130859375e-05), (11, 4.649162292480469e-05), (12, 23.595736503601074), (13, 8.726119995117188e-05), (14, 9.72747802734375e-05), (15, 6.961822509765625e-05)]
# 23/05/05 00:33:55 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@7655c0b4{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [5adf4e4d54a24dc79eed7eb035366f8a] finished successfully.
# done: true
# driverControlFilesUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/e8d4a3fa-f3ec-4857-bcd2-58386584782b/jobs/5adf4e4d54a24dc79eed7eb035366f8a/
# driverOutputResourceUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/e8d4a3fa-f3ec-4857-bcd2-58386584782b/jobs/5adf4e4d54a24dc79eed7eb035366f8a/driveroutput
# jobUuid: fcd4dc57-a2c1-3e62-aef4-c31d618bbe21
# placement:
#   clusterName: big-data-adcy439-maximal-cluster-4-workers
#   clusterUuid: e8d4a3fa-f3ec-4857-bcd2-58386584782b
# pysparkJob:
#   mainPythonFileUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/e8d4a3fa-f3ec-4857-bcd2-58386584782b/jobs/5adf4e4d54a24dc79eed7eb035366f8a/staging/spark_write_tfrec16.py
# reference:
#   jobId: 5adf4e4d54a24dc79eed7eb035366f8a
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-05-05T00:33:57.229111Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-05-05T00:33:05.263570Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-05-05T00:33:05.353834Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-05-05T00:33:05.652163Z'
# yarnApplications:
# - name: spark_write_tfrec16.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-maximal-cluster-4-workers-m:8088/proxy/application_1683245425808_0002/

# %%
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER \
spark_write_tfrec16.py
# %time
# Out:
# Job [3b88fe8b086b43f0a40fc4d2fb0150b3] submitted.
# Waiting for job output...
# 2023-04-28 14:33:47.712847: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-04-28 14:33:47.712892: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.4.0
# 23/04/28 14:33:50 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/04/28 14:33:50 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/04/28 14:33:50 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/04/28 14:33:50 INFO org.spark_project.jetty.util.log: Logging initialized @5571ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/04/28 14:33:50 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/04/28 14:33:50 INFO org.spark_project.jetty.server.Server: Started @5674ms
# 23/04/28 14:33:50 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@3a6d2388{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/04/28 14:33:51 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/04/28 14:33:51 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-maximal-cluster-m/10.128.0.2:8032
# 23/04/28 14:33:51 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-maximal-cluster-m/10.128.0.2:10200
# 23/04/28 14:33:54 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1682691957274_0001
# gs://flowers-public/tfrecords-jpeg-192x192-2/flowers00-230.tfrec
# [(0, 9.703636169433594e-05), (1, 9.942054748535156e-05), (2, 9.131431579589844e-05), (3, 8.296966552734375e-05), (4, 32.44933342933655), (5, 0.00010538101196289062), (6, 8.106231689453125e-05), (7, 5.459785461425781e-05), (8, 7.700920104980469e-05), (9, 7.534027099609375e-05), (10, 7.963180541992188e-05), (11, 0.00010824203491210938), (12, 32.82298302650452), (13, 5.2928924560546875e-05), (14, 7.987022399902344e-05), (15, 8.416175842285156e-05)]
# 23/04/28 14:34:50 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@3a6d2388{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [3b88fe8b086b43f0a40fc4d2fb0150b3] finished successfully.
# done: true
# driverControlFilesUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/5f561eb9-e797-4d51-963e-d734df57b8f0/jobs/3b88fe8b086b43f0a40fc4d2fb0150b3/
# driverOutputResourceUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/5f561eb9-e797-4d51-963e-d734df57b8f0/jobs/3b88fe8b086b43f0a40fc4d2fb0150b3/driveroutput
# jobUuid: 145794ba-3c65-341d-b3f1-f3f940b2c271
# placement:
#   clusterName: big-data-adcy439-maximal-cluster
#   clusterUuid: 5f561eb9-e797-4d51-963e-d734df57b8f0
# pysparkJob:
#   mainPythonFileUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/5f561eb9-e797-4d51-963e-d734df57b8f0/jobs/3b88fe8b086b43f0a40fc4d2fb0150b3/staging/spark_write_tfrec16.py
# reference:
#   jobId: 3b88fe8b086b43f0a40fc4d2fb0150b3
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-04-28T14:34:52.655842Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-04-28T14:33:43.345509Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-04-28T14:33:43.387506Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-04-28T14:33:43.694245Z'
# yarnApplications:
# - name: spark_write_tfrec16.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-maximal-cluster-m:8088/proxy/application_1682691957274_0001/
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 21.7 µs

# %%
#1)d)ii :
# creating the cluster (medium cluster)
CLUSTER = '{}-16-cluster'.format(PROJECT)
# !gcloud dataproc clusters create $CLUSTER --region $REGION \
    --image-version 1.4-ubuntu18 \
    --master-machine-type n1-standard-2 \
    --worker-machine-type n1-standard-2 \
    --num-workers 3 \
    --master-boot-disk-type pd-ssd \
    --master-boot-disk-size 100 \
    --worker-boot-disk-type pd-standard \
    --worker-boot-disk-size 250 \
    --initialization-actions gs://goog-dataproc-initialization-actions-$REGION/python/pip-install.sh \
    --metadata PIP_PACKAGES="tensorflow numpy" \
    --max-idle 3600s
# Out:
# Waiting on operation [projects/big-data-adcy439/regions/us-central1/operations/47d6667a-58ab-3077-8dea-89f8e01a8663].
#
# WARNING: Don't create production clusters that reference initialization actions located in the gs://goog-dataproc-initialization-actions-REGION public buckets. These scripts are provided as reference implementations, and they are synchronized with ongoing GitHub repository changes—a new version of a initialization action in public buckets may break your cluster creation. Instead, copy the following initialization actions from public buckets into your bucket : gs://goog-dataproc-initialization-actions-us-central1/python/pip-install.sh
# WARNING: Failed to validate permissions required for default service account: '175564710579-compute@developer.gserviceaccount.com'. Cluster creation could still be successful if required permissions have been granted to the respective service accounts as mentioned in the document https://cloud.google.com/dataproc/docs/concepts/configuring-clusters/service-accounts#dataproc_service_accounts_2. This could be due to Cloud Resource Manager API hasn't been enabled in your project '175564710579' before or it is disabled. Enable it by visiting 'https://console.developers.google.com/apis/api/cloudresourcemanager.googleapis.com/overview?project=175564710579'.
# WARNING: For PD-Standard without local SSDs, we strongly recommend provisioning 1TB or larger to ensure consistently high I/O performance. See https://cloud.google.com/compute/docs/disks/performance for information on disk I/O performance.
# Created [https://dataproc.googleapis.com/v1/projects/big-data-adcy439/regions/us-central1/clusters/big-data-adcy439-16-cluster] Cluster placed in zone [us-central1-b].

# %%
# running the file in the cluster ( with two partitions)
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_write_tfrec.py
# Out:
# Job [a9ae63322aa340f5a0b219b7ee4880b4] submitted.
# Waiting for job output...
# 2023-05-05 22:36:48.948641: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 22:36:48.948685: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.6.2
# 23/05/05 22:36:51 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 22:36:51 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 22:36:51 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 22:36:52 INFO org.spark_project.jetty.util.log: Logging initialized @6017ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 22:36:52 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 22:36:52 INFO org.spark_project.jetty.server.Server: Started @6191ms
# 23/05/05 22:36:52 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@585678c2{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 22:36:52 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 22:36:53 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-16-cluster-m/10.128.15.192:8032
# 23/05/05 22:36:54 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-16-cluster-m/10.128.15.192:10200
# 23/05/05 22:36:57 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683326058911_0001
# gs://flowers-public/daisy/100080576_f52e8ee070_n.jpg
# 23/05/05 22:37:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 0 contains a task of very large size (134 KB). The maximum recommended task size is 100 KB.
# [('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-0.tfrec', 1537.9826917648315), ('gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/flowers/tfrecords-test/flowers-spark-1.tfrec', 1221.289392232895)]
# 23/05/05 23:02:55 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@585678c2{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [a9ae63322aa340f5a0b219b7ee4880b4] finished successfully.
# done: true
# driverControlFilesUri: gs://dataproc-staging-us-central1-175564710579-hnx3c2fg/google-cloud-dataproc-metainfo/cace902d-d57d-4427-9ca4-54c142e6c0a2/jobs/a9ae63322aa340f5a0b219b7ee4880b4/
# driverOutputResourceUri: gs://dataproc-staging-us-central1-175564710579-hnx3c2fg/google-cloud-dataproc-metainfo/cace902d-d57d-4427-9ca4-54c142e6c0a2/jobs/a9ae63322aa340f5a0b219b7ee4880b4/driveroutput
# jobUuid: cc06ec49-080f-3d33-a5a3-7f15425f63ff
# placement:
#   clusterName: big-data-adcy439-16-cluster
#   clusterUuid: cace902d-d57d-4427-9ca4-54c142e6c0a2
# pysparkJob:
#   mainPythonFileUri: gs://dataproc-staging-us-central1-175564710579-hnx3c2fg/google-cloud-dataproc-metainfo/cace902d-d57d-4427-9ca4-54c142e6c0a2/jobs/a9ae63322aa340f5a0b219b7ee4880b4/staging/spark_write_tfrec.py
# reference:
#   jobId: a9ae63322aa340f5a0b219b7ee4880b4
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-05-05T23:02:57.361391Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-05-05T22:36:44.387119Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-05-05T22:36:44.423468Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-05-05T22:36:44.745806Z'
# yarnApplications:
# - name: spark_write_tfrec.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-16-cluster-m:8088/proxy/application_1683326058911_0001/

# %%
# run the file in the cluster (with 16 partitions)
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_write_tfrec16.py
# Out:
# Job [a70f541c7a9445ff9053d5c07c0ab766] submitted.
# Waiting for job output...
# 2023-05-05 23:05:17.646536: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 23:05:17.646580: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.6.2
# 23/05/05 23:05:20 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 23:05:20 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 23:05:20 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 23:05:20 INFO org.spark_project.jetty.util.log: Logging initialized @5484ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 23:05:20 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 23:05:20 INFO org.spark_project.jetty.server.Server: Started @5620ms
# 23/05/05 23:05:20 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@2b8517a1{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 23:05:20 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 23:05:21 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-16-cluster-m/10.128.15.192:8032
# 23/05/05 23:05:22 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-16-cluster-m/10.128.15.192:10200
# 23/05/05 23:05:24 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683326058911_0002
# gs://flowers-public/tfrecords-jpeg-192x192-2/flowers00-230.tfrec
# [(0, 7.605552673339844e-05), (1, 7.05718994140625e-05), (2, 8.511543273925781e-05), (3, 5.173683166503906e-05), (4, 32.94297456741333), (5, 5.53131103515625e-05), (6, 5.53131103515625e-05), (7, 5.435943603515625e-05), (8, 5.3882598876953125e-05), (9, 7.033348083496094e-05), (10, 4.7206878662109375e-05), (11, 7.486343383789062e-05), (12, 31.64999032020569), (13, 4.673004150390625e-05), (14, 7.748603820800781e-05), (15, 5.9604644775390625e-05)]
# 23/05/05 23:06:13 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@2b8517a1{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [a70f541c7a9445ff9053d5c07c0ab766] finished successfully.
# done: true
# driverControlFilesUri: gs://dataproc-staging-us-central1-175564710579-hnx3c2fg/google-cloud-dataproc-metainfo/cace902d-d57d-4427-9ca4-54c142e6c0a2/jobs/a70f541c7a9445ff9053d5c07c0ab766/
# driverOutputResourceUri: gs://dataproc-staging-us-central1-175564710579-hnx3c2fg/google-cloud-dataproc-metainfo/cace902d-d57d-4427-9ca4-54c142e6c0a2/jobs/a70f541c7a9445ff9053d5c07c0ab766/driveroutput
# jobUuid: 9f858be0-0931-3468-b12e-1edcd25b4e79
# placement:
#   clusterName: big-data-adcy439-16-cluster
#   clusterUuid: cace902d-d57d-4427-9ca4-54c142e6c0a2
# pysparkJob:
#   mainPythonFileUri: gs://dataproc-staging-us-central1-175564710579-hnx3c2fg/google-cloud-dataproc-metainfo/cace902d-d57d-4427-9ca4-54c142e6c0a2/jobs/a70f541c7a9445ff9053d5c07c0ab766/staging/spark_write_tfrec16.py
# reference:
#   jobId: a70f541c7a9445ff9053d5c07c0ab766
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-05-05T23:06:17.500364Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-05-05T23:05:13.391027Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-05-05T23:05:13.421797Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-05-05T23:05:13.666129Z'
# yarnApplications:
# - name: spark_write_tfrec16.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-16-cluster-m:8088/proxy/application_1683326058911_0002/

# %%
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER \
 spark_write_tfrec16.py
# Out:
# Job [25d9aa5129894a1e8627024ad10f3700] submitted.
# Waiting for job output...
# 2023-04-23 18:33:57.848249: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-04-23 18:33:57.848434: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.6.2
# 23/04/23 18:34:01 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/04/23 18:34:01 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/04/23 18:34:01 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/04/23 18:34:01 INFO org.spark_project.jetty.util.log: Logging initialized @7962ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/04/23 18:34:02 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/04/23 18:34:02 INFO org.spark_project.jetty.server.Server: Started @8239ms
# 23/04/23 18:34:02 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@21d967bc{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/04/23 18:34:02 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/04/23 18:34:04 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-cluster-max-m/10.128.15.218:8032
# 23/04/23 18:34:04 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-cluster-max-m/10.128.15.218:10200
# 23/04/23 18:34:08 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1682274530368_0001
# gs://flowers-public/tfrecords-jpeg-192x192-2/flowers00-230.tfrec
# [(0, 0.000102996826171875), (1, 8.630752563476562e-05), (2, 7.843971252441406e-05), (3, 8.296966552734375e-05), (4, 28.302613735198975), (5, 5.2928924560546875e-05), (6, 6.341934204101562e-05), (7, 5.173683166503906e-05), (8, 5.53131103515625e-05), (9, 5.435943603515625e-05), (10, 5.435943603515625e-05), (11, 5.054473876953125e-05), (12, 41.28642010688782), (13, 6.0558319091796875e-05), (14, 9.512901306152344e-05), (15, 5.245208740234375e-05)]
# 23/04/23 18:35:21 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@21d967bc{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [25d9aa5129894a1e8627024ad10f3700] finished successfully.
# done: true
# driverControlFilesUri: gs://dataproc-staging-us-central1-175564710579-hnx3c2fg/google-cloud-dataproc-metainfo/6b3d3d1f-eadf-4651-b848-1fe25c36ebfe/jobs/25d9aa5129894a1e8627024ad10f3700/
# driverOutputResourceUri: gs://dataproc-staging-us-central1-175564710579-hnx3c2fg/google-cloud-dataproc-metainfo/6b3d3d1f-eadf-4651-b848-1fe25c36ebfe/jobs/25d9aa5129894a1e8627024ad10f3700/driveroutput
# jobUuid: 9b48ca13-ea60-3974-afce-0e6486cc005c
# placement:
#   clusterName: big-data-adcy439-cluster-max
#   clusterUuid: 6b3d3d1f-eadf-4651-b848-1fe25c36ebfe
# pysparkJob:
#   mainPythonFileUri: gs://dataproc-staging-us-central1-175564710579-hnx3c2fg/google-cloud-dataproc-metainfo/6b3d3d1f-eadf-4651-b848-1fe25c36ebfe/jobs/25d9aa5129894a1e8627024ad10f3700/staging/spark_write_tfrec16.py
# reference:
#   jobId: 25d9aa5129894a1e8627024ad10f3700
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-04-23T18:35:23.697935Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-04-23T18:33:52.393145Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-04-23T18:33:52.431851Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-04-23T18:33:52.639128Z'
# yarnApplications:
# - name: spark_write_tfrec16.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-cluster-max-m:8088/proxy/application_1682274530368_0001/

# %% [markdown]
# # Section 2: Speed tests
#
# We have seen that **reading from the pre-processed TFRecord files** is **faster** than reading individual image files and decoding on the fly.
# This task is about **measuring this effect** and **parallelizing the tests with PySpark**.

# %% [markdown]
# ## 2.1 Speed test implementation
#
# Here is **code for time measurement** to determine the **throughput in images per second**.
# It doesn't render the images but extracts and prints some basic information in order to make sure the image data are read.
# We write the information to the null device for longer measurements `null_file=open("/dev/null", mode='w')`.
# That way it will not clutter our cell output.
#
# We use batches ( `dset2 = dset1.batch(batch_size)` ) and select a number of batches with (`dset3 = dset2.take(batch_number)`).
# Then we  use the `time.time()` to take the **time measurement** and take it multiple times, reading from the same dataset to see if reading speed changes with mutiple readings.
#
# We then **vary** the size of the batch (`batch_size`) and the number of batches (`batch_number`) and **store the results for different values**.
# Store also the **results for each repetition** over the same dataset (repeat 2 or 3 times).
#
# The speed test should be combined in a **function** `time_configs()` that takes a configuration, i.e. a dataset and arrays of `batch_sizes`, `batch_numbers`, and  `repetitions` (an array of integers starting from 1), as **arguments** and runs the time measurement for each combination of batch_size and batch_number for the requested number of repetitions.

# %%
# Here are some useful values for testing your code, use higher values later for actually testing throughput
batch_sizes = [2,4] 
batch_numbers = [3,6] 
repetitions = [1]

def time_configs(dataset, batch_sizes, batch_numbers, repetitions): 
    dims = [len(batch_sizes),len(batch_numbers),len(repetitions)] 
    print(dims) 
    results = np.zeros(dims) 
    params = np.zeros(dims + [3]) 
    print( results.shape ) 
    with open("/dev/null",mode='w') as null_file: # for printing the output without showing it
        tt = time.time() # for overall time taking 
        for bsi,bs in enumerate(batch_sizes): 
            for dsi, ds in enumerate(batch_numbers): 
                batched_dataset = dataset.batch(bs)  
                timing_set = batched_dataset.take(ds) 
                for ri,rep in enumerate(repetitions): 
                    print("bs: {}, ds: {}, rep: {}".format(bs,ds,rep)) 
                    t0 = time.time() 
                    for image, label in timing_set: 
                        #print("Image batch shape {}".format(image.numpy().shape),
                        print("Image batch shape {}, {})".format(image.numpy().shape, 
                            [str(lbl) for lbl in label.numpy()]), null_file)
                    td = time.time() - t0 # duration for reading images
                    results[bsi,dsi,ri] = ( bs * ds) / td 
                    params[bsi,dsi,ri] = [ bs, ds, rep ]
    print("total time: "+str(time.time()-tt))
    return results, params

# %% [markdown]
# **Let's try this function** with a **small number** of configurations of batch_sizes batch_numbers and repetions, so that we get a set of parameter combinations and corresponding reading speeds.
# Try reading from the image files (dataset2) and the TFRecord files (datasetDecoded).

# %%
[res,par] = time_configs(dataset4, batch_sizes, batch_numbers, repetitions)
print(res) 
print(par) 

print("=============")

[res,par] = time_configs(datasetTfrec, batch_sizes, batch_numbers, repetitions)
print(res)
print(par)
# Out:
# [2, 2, 1]
# (2, 2, 1)
# bs: 2, ds: 3, rep: 1
# Image batch shape (2,), ["b'dandelion'", "b'daisy'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2,), ["b'tulips'", "b'dandelion'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2,), ["b'daisy'", "b'roses'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# bs: 2, ds: 6, rep: 1
# Image batch shape (2,), ["b'roses'", "b'dandelion'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2,), ["b'daisy'", "b'roses'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2,), ["b'dandelion'", "b'roses'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2,), ["b'roses'", "b'dandelion'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2,), ["b'tulips'", "b'daisy'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2,), ["b'tulips'", "b'dandelion'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# bs: 4, ds: 3, rep: 1
# Image batch shape (4,), ["b'dandelion'", "b'roses'", "b'dandelion'", "b'sunflowers'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4,), ["b'dandelion'", "b'tulips'", "b'roses'", "b'dandelion'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4,), ["b'tulips'", "b'daisy'", "b'tulips'", "b'sunflowers'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# bs: 4, ds: 6, rep: 1
# Image batch shape (4,), ["b'dandelion'", "b'tulips'", "b'tulips'", "b'tulips'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4,), ["b'tulips'", "b'dandelion'", "b'daisy'", "b'dandelion'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4,), ["b'roses'", "b'dandelion'", "b'roses'", "b'dandelion'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4,), ["b'dandelion'", "b'sunflowers'", "b'sunflowers'", "b'daisy'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4,), ["b'roses'", "b'tulips'", "b'daisy'", "b'sunflowers'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4,), ["b'daisy'", "b'daisy'", "b'daisy'", "b'sunflowers'"]) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# total time: 3.437811851501465
# [[[ 8.47952547]
#   [15.12380592]]
#
#  [[16.01164584]
#   [20.3772308 ]]]
# [[[[2. 3. 1.]]
#
#   [[2. 6. 1.]]]
#
#
#  [[[4. 3. 1.]]
#
#   [[4. 6. 1.]]]]
# =============
# [2, 2, 1]
# (2, 2, 1)
# bs: 2, ds: 3, rep: 1
# Image batch shape (2, 192, 192, 3), ['0', '0']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2, 192, 192, 3), ['0', '0']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2, 192, 192, 3), ['1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# bs: 2, ds: 6, rep: 1
# Image batch shape (2, 192, 192, 3), ['0', '0']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2, 192, 192, 3), ['0', '0']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2, 192, 192, 3), ['1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2, 192, 192, 3), ['1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2, 192, 192, 3), ['1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (2, 192, 192, 3), ['1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# bs: 4, ds: 3, rep: 1
# Image batch shape (4, 192, 192, 3), ['0', '0', '0', '0']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4, 192, 192, 3), ['1', '1', '1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4, 192, 192, 3), ['1', '1', '1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# bs: 4, ds: 6, rep: 1
# Image batch shape (4, 192, 192, 3), ['0', '0', '0', '0']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4, 192, 192, 3), ['1', '1', '1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4, 192, 192, 3), ['1', '1', '1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4, 192, 192, 3), ['1', '1', '0', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4, 192, 192, 3), ['1', '1', '1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# Image batch shape (4, 192, 192, 3), ['1', '1', '1', '1']) <_io.TextIOWrapper name='/dev/null' mode='w' encoding='UTF-8'>
# total time: 2.7661590576171875
# [[[15.18939741]
#   [18.54442558]]
#
#  [[19.11963225]
#   [22.00477243]]]
# [[[[2. 3. 1.]]
#
#   [[2. 6. 1.]]]
#
#
#  [[[4. 3. 1.]]
#
#   [[4. 6. 1.]]]]

# %% [markdown]
# ## Task 2: Parallelising the speed test with Spark in the cloud. (36%)
#
# As an exercise in **Spark programming and optimisation** as well as **performance analysis**, we will now implement the **speed test** with multiple parameters in parallel with Spark.
# Runing multiple tests in parallel would **not be a useful approach on a single machine, but it can be in the cloud** (you will be asked to reason about this later).

# %% [markdown]
# ### 2a) Create the script (14%)
# Your task is now to **port the speed test above to Spark** for running it in the cloud in Dataproc.
# **Adapt the speed testing** as a Spark program that performs the same actions as above, but **with Spark RDDs in a distributed way**.
# The distribution should be such that **each parameter combination (except repetition)** is processed in a separate Spark task.
#
# More specifically:
# *   i) combine the previous cells to have the code to create a dataset and create a list of parameter combin
# ations in an RDD (2%)
# *   ii) get a Spark context and  create the dataset and run timing test for each combination in parallel (2%)
# *   iii) transform the resulting RDD to the structure \( parameter_combination, images_per_second \) and save these values in an array (2%)
# *   iv) create an RDD with all results for each parameter as (parameter_value,images_per_second) and collect the result for each parameter  (2%)
# *   v) create an RDD with the average reading speeds for each parameter value and collect the results. Keep associativity in mind when implementing the average. (3%)
# *   vi) write the results to a pickle file in your bucket (2%)
# *   vii) Write your code it into a file using the *cell magic* `%%writefile spark_job.py` (1%)
#
#
# **Important:** The task here is not to parallelize the pre-processing, but to run multiple speed tests in parallel using Spark.

# %%
# Task i:
import time
import subprocess
dsetFiles = tf.data.Dataset.list_files(GCS_PATTERN) 
dsetDecoded = dsetFiles.map(decode_jpeg_and_label)
dsetResized = dsetDecoded.map(resize_and_crop_image)  
dsetRecompressed = dsetResized.map(recompress_image) # creating the dataset

batch_sizes = [2,4,6,8] 
batch_numbers = [3,6,9,15] 
repetitions = [1,2,5,9]

filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
datasetTfrec = load_dataset(filenames)

# Creating a list of  of parameter combinations in an RDD
param_Rdd = sc.parallelize([(bs, ds, rep) for bs in batch_sizes for ds in batch_numbers for rep in repetitions])

# Task ii:
#  first, lets create a function for performing timing test for only one parameter combination:
def time_config(params):
    bs, ds, rep = params
    with open("/dev/null", mode="w") as null_file:

        dsetFiles = tf.data.Dataset.list_files(GCS_PATTERN) 
        dsetDecoded = dsetFiles.map(decode_jpeg_and_label)
        dsetResized = dsetDecoded.map(resize_and_crop_image)  
        dataset = dsetResized.map(recompress_image) # creating the dataset( same as we did in task i)
      
        batched_dataset = dataset.batch(bs)
        timing_set = batched_dataset.take(ds)
        results = []
        for i in range(rep):
            t0 = time.time()
            for image, label in timing_set:
                print("Image batch shape {}, {})".format(image.numpy().shape, [str(lbl) for lbl in label.numpy()]), null_file)
            td = time.time() - t0
            results.append((bs * ds) / td)
        return (params,sum(results) / rep)

def time_config_tfrec(params):
    bs, ds, rep = params
    with open("/dev/null", mode="w") as null_file:

     

        filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
        dataset = load_dataset(filenames) # creating the dataset( same as we did in task i)
      
        batched_dataset = dataset.batch(bs)
        timing_set = batched_dataset.take(ds)
        results = []
        for i in range(rep):
            t0 = time.time()
            for image, label in timing_set:
                print("Image batch shape {}, {})".format(image.numpy().shape, [str(lbl) for lbl in label.numpy()]), null_file)
            td = time.time() - t0
            results.append((bs * ds) / td)
        return (params,sum(results) / rep)

# Now, we run the timing test for each combination in pararell
results_img_rdd = param_Rdd.map(time_config)

results_tf_rdd = param_Rdd.map(time_config_tfrec)


# Collecting the results 
results = results_img_rdd.collect()
print(results)

results = results_tf_rdd.collect()
print(results)

# Task iii: 
transformed_img_rdd=results_img_rdd.map(lambda x:(x[0],x[0][0]*x[0][1]/x[1]))
transformed_tf_rdd=results_tf_rdd.map(lambda x:(x[0],x[0][0]*x[0][1]/x[1]))

transformed_img_rdd.collect()
transformed_tf_rdd.collect()

# Task iv:

# for images
transformed_img_bn=transformed_img_rdd.map(lambda x:(x[0][1],x[1]))
transformed_img_bs=transformed_img_rdd.map(lambda x:(x[0][0],x[1]))
transformed_img_rep=transformed_img_rdd.map(lambda x:(x[0][2],x[1]))
transformed_img_ds=transformed_img_rdd.map(lambda x:(x[0][0]*x[0][1],x[1]))

transformed_img_bn.collect()
transformed_img_bs.collect()
transformed_img_rep.collect() 
transformed_img_ds.collect()

# for tfrecord files
transformed_tf_bn=transformed_tf_rdd.map(lambda x:(x[0][1],x[1]))
transformed_tf_bs=transformed_tf_rdd.map(lambda x:(x[0][0],x[1]))
transformed_tf_rep=transformed_tf_rdd.map(lambda x:(x[0][2],x[1]))
transformed_tf_ds=transformed_tf_rdd.map(lambda x:(x[0][0]*x[0][1],x[1]))

transformed_tf_bn.collect()
transformed_tf_bs.collect()
transformed_tf_rep.collect()
transformed_tf_ds.collect()
# print(transformed_rdd.collect())

# Task v:

transformed_rdd3=transformed_img_bn.groupByKey().mapValues(list)
transformed_rdd4=transformed_img_bs.groupByKey().mapValues(list)
transformed_rdd5=transformed_img_rep.groupByKey().mapValues(list)
transformed_rdd6=transformed_img_ds.groupByKey().mapValues(list)


transformed_rdd7=transformed_tf_bn.groupByKey().mapValues(list)
transformed_rdd8=transformed_tf_bs.groupByKey().mapValues(list)
transformed_rdd9=transformed_tf_rep.groupByKey().mapValues(list)
transformed_rdd10=transformed_tf_ds.groupByKey().mapValues(list)

# collecting them :

transformed_rdd3_coll=transformed_rdd3.collect()
transformed_rdd4_coll=transformed_rdd4.collect()
transformed_rdd5_coll=transformed_rdd5.collect()
transformed_rdd6_coll=transformed_rdd6.collect()

transformed_rdd7_coll=transformed_rdd7.collect()
transformed_rdd8_coll=transformed_rdd8.collect()
transformed_rdd9_coll=transformed_rdd9.collect()
transformed_rdd10_coll=transformed_rdd10.collect()

# getting the averages:

transformed_rdd3_avg=transformed_rdd3.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd4_avg=transformed_rdd4.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd5_avg=transformed_rdd5.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd6_avg=transformed_rdd6.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))

transformed_rdd7_avg=transformed_rdd7.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd8_avg=transformed_rdd8.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd9_avg=transformed_rdd9.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd10_avg=transformed_rdd10.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))


# collecting them:

transformed_rdd3_avg_coll=transformed_rdd3_avg.collect()
transformed_rdd4_avg_coll=transformed_rdd4_avg.collect()
transformed_rdd5_avg_coll=transformed_rdd5_avg.collect()
transformed_rdd6_avg_coll=transformed_rdd6_avg.collect()

transformed_rdd7_avg_coll=transformed_rdd7_avg.collect()
transformed_rdd8_avg_coll=transformed_rdd8_avg.collect()
transformed_rdd9_avg_coll=transformed_rdd9_avg.collect()
transformed_rdd10_avg_coll=transformed_rdd10_avg.collect()


#time  = datetime.datetime.now().strftime("%y%m%d-%H%M")


# Task vi:

with open("shiva.pickle", 'wb') as f:

    pickle.dump(transformed_rdd3_coll, f)
    pickle.dump(transformed_rdd4_coll, f)
    pickle.dump(transformed_rdd5_coll, f)
    pickle.dump(transformed_rdd6_coll, f)
    pickle.dump(transformed_rdd7_coll, f)
    pickle.dump(transformed_rdd8_coll, f)
    pickle.dump(transformed_rdd9_coll, f)
    pickle.dump(transformed_rdd10_coll, f)


    pickle.dump(transformed_rdd3_avg_coll, f)
    pickle.dump(transformed_rdd4_avg_coll, f)
    pickle.dump(transformed_rdd5_avg_coll, f)
    pickle.dump(transformed_rdd6_avg_coll, f)
    pickle.dump(transformed_rdd7_avg_coll, f)
    pickle.dump(transformed_rdd8_avg_coll, f)
    pickle.dump(transformed_rdd9_avg_coll, f)
    pickle.dump(transformed_rdd10_avg_coll, f)
f.close()
subprocess.run(["gsutil","cp","shiva.pickle",BUCKET+"/shiva.pickle"],check=True)
# Out:
# [((2, 3, 1), 10.906274120105067), ((2, 3, 2), 11.80105638400887), ((2, 3, 5), 10.310431612227296), ((2, 3, 9), 14.538829614356239), ((2, 6, 1), 19.16419287997204), ((2, 6, 2), 21.03004068664154), ((2, 6, 5), 19.83160020910326), ((2, 6, 9), 19.796172651161854), ((2, 9, 1), 23.920620169971993), ((2, 9, 2), 24.832765617476902), ((2, 9, 5), 21.532722632648003), ((2, 9, 9), 23.71901754915133), ((2, 15, 1), 28.318818608855032), ((2, 15, 2), 18.20668144104183), ((2, 15, 5), 28.67837288839241), ((2, 15, 9), 24.587347435843057), ((4, 3, 1), 20.567883849406993), ((4, 3, 2), 19.186875821252364), ((4, 3, 5), 21.92227701324585), ((4, 3, 9), 18.126493342629047), ((4, 6, 1), 22.966102039070297), ((4, 6, 2), 27.551940904530163), ((4, 6, 5), 19.791394985919318), ((4, 6, 9), 25.397732367784574), ((4, 9, 1), 16.61259807399631), ((4, 9, 2), 30.04251863352694), ((4, 9, 5), 28.24000200722598), ((4, 9, 9), 18.51161459086651), ((4, 15, 1), 32.45422511416962), ((4, 15, 2), 32.82545487252085), ((4, 15, 5), 30.0019552956501), ((4, 15, 9), 30.429424873811936), ((6, 3, 1), 22.47950113488063), ((6, 3, 2), 20.159899362747957), ((6, 3, 5), 20.37515605761756), ((6, 3, 9), 22.661724691397996), ((6, 6, 1), 19.550849383370164), ((6, 6, 2), 27.29339978670389), ((6, 6, 5), 28.458826916627316), ((6, 6, 9), 26.656976073652913), ((6, 9, 1), 18.170350210129286), ((6, 9, 2), 32.59967892616275), ((6, 9, 5), 27.86656195291307), ((6, 9, 9), 26.840201601023352), ((6, 15, 1), 22.726333869752978), ((6, 15, 2), 29.260710530098805), ((6, 15, 5), 30.116448759706202), ((6, 15, 9), 25.8037130356649), ((8, 3, 1), 26.82875043842489), ((8, 3, 2), 24.530884800557516), ((8, 3, 5), 25.558946535793012), ((8, 3, 9), 25.106530513828805), ((8, 6, 1), 32.28258426678023), ((8, 6, 2), 28.42725860043703), ((8, 6, 5), 38.756415810538904), ((8, 6, 9), 37.165297281272366), ((8, 9, 1), 39.79764827558396), ((8, 9, 2), 32.68356995741851), ((8, 9, 5), 39.00346296740726), ((8, 9, 9), 37.44097562324383), ((8, 15, 1), 40.906516593782904), ((8, 15, 2), 27.31134032892343), ((8, 15, 5), 38.72959649950432), ((8, 15, 9), 40.6822093853007)]
# [((2, 3, 1), 14.933815662279539), ((2, 3, 2), 17.356914177008413), ((2, 3, 5), 13.002377244322162), ((2, 3, 9), 17.481528082805127), ((2, 6, 1), 20.045054294710397), ((2, 6, 2), 21.28805733037379), ((2, 6, 5), 22.20375337656792), ((2, 6, 9), 19.72621698659473), ((2, 9, 1), 23.252055796947012), ((2, 9, 2), 23.122205731441383), ((2, 9, 5), 23.025966053518523), ((2, 9, 9), 21.277333735381568), ((2, 15, 1), 23.911762073357913), ((2, 15, 2), 23.99302064703423), ((2, 15, 5), 21.191733117103816), ((2, 15, 9), 22.4292445006512), ((4, 3, 1), 22.1608952479579), ((4, 3, 2), 17.418221819994063), ((4, 3, 5), 23.385515682213523), ((4, 3, 9), 20.088378236709787), ((4, 6, 1), 23.5602076301117), ((4, 6, 2), 24.99864050825183), ((4, 6, 5), 24.06524119918114), ((4, 6, 9), 22.739655253783788), ((4, 9, 1), 23.374941193025737), ((4, 9, 2), 22.835541689678248), ((4, 9, 5), 22.41671377969207), ((4, 9, 9), 23.940387547913883), ((4, 15, 1), 11.69993651138425), ((4, 15, 2), 24.673851632823144), ((4, 15, 5), 22.97198888196024), ((4, 15, 9), 24.124698959555513), ((6, 3, 1), 20.190306563299533), ((6, 3, 2), 23.3296137029212), ((6, 3, 5), 22.59473762359667), ((6, 3, 9), 20.473025568959716), ((6, 6, 1), 23.683857906524683), ((6, 6, 2), 23.738010676072406), ((6, 6, 5), 22.3495439120184), ((6, 6, 9), 21.271857782102305), ((6, 9, 1), 25.113916325390566), ((6, 9, 2), 22.67345934490927), ((6, 9, 5), 21.72063373587806), ((6, 9, 9), 24.56135789366724), ((6, 15, 1), 24.019291923196523), ((6, 15, 2), 21.56474416658952), ((6, 15, 5), 23.925525589049464), ((6, 15, 9), 24.243678416098675), ((8, 3, 1), 23.014992407084527), ((8, 3, 2), 16.84931042202393), ((8, 3, 5), 25.490601315193313), ((8, 3, 9), 24.533530526055042), ((8, 6, 1), 27.033257794331877), ((8, 6, 2), 23.223516057100586), ((8, 6, 5), 24.611218678049262), ((8, 6, 9), 22.63326262696113), ((8, 9, 1), 25.770096249412365), ((8, 9, 2), 26.507234964844837), ((8, 9, 5), 26.015345793202943), ((8, 9, 9), 23.44285350012582), ((8, 15, 1), 27.6105535238262), ((8, 15, 2), 25.06782514592944), ((8, 15, 5), 25.782274615163352), ((8, 15, 9), 25.94727371354992)]
# CompletedProcess(args=['gsutil', 'cp', 'shiva.pickle', 'gs://big-data-adcy439-storage/shiva.pickle'], returncode=0)

# %%
results_tf_rdd.take(3)
# Out:
# [((2, 3, 1), 17.110470938988364),
#  ((2, 6, 1), 19.76611633861669),
#  ((4, 3, 1), 19.82951352897445)]

# %%
# Task vi continue... :
# !gsutil cp ./shiva.pickle $BUCKET # writing the file in the bucket

# %%
# Task vii :
# %%writefile spark_job.py
import os, sys, math
import numpy as np
import scipy as sp
import scipy.stats
import time
import datetime
import string
import random
import pyspark 
from matplotlib import pyplot as plt
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
import pickle
import subprocess


def decode_jpeg_and_label(filepath):
    # extracts the image data and creates a class label, based on the filepath 
    bits = tf.io.read_file(filepath)
    image = tf.image.decode_jpeg(bits)
    # parse flower name from containing directory
    label = tf.strings.split(tf.expand_dims(filepath, axis=-1), sep='/')
    label2 = label.values[-2]
    return image, label2

def resize_and_crop_image(image, label):
    # Resizes and cropd using "fill" algorithm:
    # always make sure the resulting image is cut out from the source image 
    # so that it fills the TARGET_SIZE entirely with no black bars 
    # and a preserved aspect ratio.
    w = tf.shape(image)[0]
    h = tf.shape(image)[1]
    tw = TARGET_SIZE[1]
    th = TARGET_SIZE[0]
    resize_crit = (w * th) / (h * tw)
    image = tf.cond(resize_crit < 1,
                    lambda: tf.image.resize(image, [w*tw/w, h*tw/w]), # if true
                    lambda: tf.image.resize(image, [w*th/h, h*th/h])  # if false
                    )
    nw = tf.shape(image)[0]
    nh = tf.shape(image)[1]
    image = tf.image.crop_to_bounding_box(image, (nw - tw) // 2, (nh - th) // 2, tw, th)
    return image, label

def recompress_image(image, label):
    # this reduces the amount of data, but takes some time
    image = tf.cast(image, tf.uint8)
    image = tf.image.encode_jpeg(image, optimize_size=True, chroma_downsampling=False)
    return image, label




def read_tfrecord(example):
    features = {
        "image": tf.io.FixedLenFeature([], tf.string),  # tf.string = bytestring (not text string)
        "class": tf.io.FixedLenFeature([], tf.int64) #,   # shape [] means scalar
    }
    # decode the TFRecord
    example = tf.io.parse_single_example(example, features)
    image = tf.image.decode_jpeg(example['image'], channels=3)
    image = tf.reshape(image, [*TARGET_SIZE, 3])    
    class_num = example['class']
    return image, class_num 


def load_dataset(filenames):
    # read from TFRecords. For optimal performance, read from multiple    
    # TFRecord files at once and set the option experimental_deterministic = False
    # to allow order-altering optimizations.
    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = False

    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.with_options(option_no_order)
    dataset = dataset.map(read_tfrecord)
    return dataset

# Task ii:
#  first, lets create a function for performing timing test for only one parameter combination:
def time_config(params):
    bs, ds, rep = params
    with open("/dev/null", mode="w") as null_file:

        dsetFiles = tf.data.Dataset.list_files(GCS_PATTERN) 
        dsetDecoded = dsetFiles.map(decode_jpeg_and_label)
        dsetResized = dsetDecoded.map(resize_and_crop_image)  
        dataset = dsetResized.map(recompress_image) # creating the dataset( same as we did in task i)
      
        batched_dataset = dataset.batch(bs)
        timing_set = batched_dataset.take(ds)
        results = []
        for i in range(rep):
            t0 = time.time()
            for image, label in timing_set:
                print("Image batch shape {}, {})".format(image.numpy().shape, [str(lbl) for lbl in label.numpy()]), null_file)
            td = time.time() - t0
            results.append((bs * ds) / td)
        return (params,sum(results) / rep)



def time_config_tfrec(params):
    bs, ds, rep = params
    with open("/dev/null", mode="w") as null_file:
        filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
        dataset = load_dataset(filenames) # creating the dataset( same as we did in task i)
      
        batched_dataset = dataset.batch(bs)
        timing_set = batched_dataset.take(ds)
        results = []
        for i in range(rep):
            t0 = time.time()
            for image, label in timing_set:
                print("Image batch shape {}, {})".format(image.numpy().shape, [str(lbl) for lbl in label.numpy()]), null_file)
            td = time.time() - t0
            results.append((bs * ds) / td)
        return (params,sum(results) / rep)

PROJECT = 'big-data-adcy439'
BUCKET = 'gs://{}-storage'.format(PROJECT)

GCS_PATTERN = 'gs://flowers-public/*/*.jpg' # glob  pattern for input files
PARTITIONS = 16 # no of partitions we will use later 
TARGET_SIZE = [192, 192] # target resolution for the images
CLASSES = [b'daisy', b'dandelion', b'roses', b'sunflowers', b'tulips']

batch_sizes = [2,4,6,8] 
batch_numbers = [3,6,9,15] 
repetitions = [1,2,5,9]

PARTITIONS = 16 # no of partitions we will use later

sc = pyspark.SparkContext.getOrCreate()


start_time = time.time()
# Task i:
dsetFiles = tf.data.Dataset.list_files(GCS_PATTERN) 
dsetDecoded = dsetFiles.map(decode_jpeg_and_label)
dsetResized = dsetDecoded.map(resize_and_crop_image)  
dsetRecompressed = dsetResized.map(recompress_image) # creating the dataset

GCS_OUTPUT = BUCKET + '/tfrecords-jpeg-192x192-2-test/flowers'

filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
datasetTfrec = load_dataset(filenames)

# Creating a list of  of parameter combinations in an RDD
 
param_Rdd = sc.parallelize([(bs, ds, rep) for bs in batch_sizes for ds in batch_numbers for rep in repetitions], 16)


# Now, we run the timing test for each combination in pararell
results_img_rdd = param_Rdd.map(time_config)

results_tf_rdd = param_Rdd.map(time_config_tfrec)


# Collecting the results 
results = results_img_rdd.collect()
print(results)

results = results_tf_rdd.collect()
print(results)

# Task iii: 
transformed_img_rdd=results_img_rdd.map(lambda x:(x[0],x[0][0]*x[0][1]/x[1]))
transformed_tf_rdd=results_tf_rdd.map(lambda x:(x[0],x[0][0]*x[0][1]/x[1]))

transformed_img_rdd.collect()
transformed_tf_rdd.collect()

# Task iv:

# for images
transformed_img_bn=transformed_img_rdd.map(lambda x:(x[0][1],x[1]))
transformed_img_bs=transformed_img_rdd.map(lambda x:(x[0][0],x[1]))
transformed_img_rep=transformed_img_rdd.map(lambda x:(x[0][2],x[1]))
transformed_img_ds=transformed_img_rdd.map(lambda x:(x[0][0]*x[0][1],x[1]))

transformed_img_bn.collect()
transformed_img_bs.collect()
transformed_img_rep.collect()
transformed_img_ds.collect()

# for tfrecord files
transformed_tf_bn=transformed_tf_rdd.map(lambda x:(x[0][1],x[1]))
transformed_tf_bs=transformed_tf_rdd.map(lambda x:(x[0][0],x[1]))
transformed_tf_rep=transformed_tf_rdd.map(lambda x:(x[0][2],x[1]))
transformed_tf_ds=transformed_tf_rdd.map(lambda x:(x[0][0]*x[0][1],x[1]))

transformed_tf_bn.collect()
transformed_tf_bs.collect()
transformed_tf_rep.collect()
transformed_tf_ds.collect()
# print(transformed_rdd.collect())

# Task v:

transformed_rdd3=transformed_img_bn.groupByKey().mapValues(list)
transformed_rdd4=transformed_img_bs.groupByKey().mapValues(list)
transformed_rdd5=transformed_img_rep.groupByKey().mapValues(list)
transformed_rdd6=transformed_img_ds.groupByKey().mapValues(list)


transformed_rdd7=transformed_tf_bn.groupByKey().mapValues(list)
transformed_rdd8=transformed_tf_bs.groupByKey().mapValues(list)
transformed_rdd9=transformed_tf_rep.groupByKey().mapValues(list)
transformed_rdd10=transformed_tf_ds.groupByKey().mapValues(list)

# collecting them :

transformed_rdd3_coll=transformed_rdd3.collect()
transformed_rdd4_coll=transformed_rdd4.collect()
transformed_rdd5_coll=transformed_rdd5.collect()
transformed_rdd6_coll=transformed_rdd6.collect()

transformed_rdd7_coll=transformed_rdd7.collect()
transformed_rdd8_coll=transformed_rdd8.collect()
transformed_rdd9_coll=transformed_rdd9.collect()
transformed_rdd10_coll=transformed_rdd10.collect()

# getting the averages:

transformed_rdd3_avg=transformed_rdd3.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd4_avg=transformed_rdd4.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd5_avg=transformed_rdd5.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd6_avg=transformed_rdd6.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))

transformed_rdd7_avg=transformed_rdd7.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd8_avg=transformed_rdd8.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd9_avg=transformed_rdd9.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd10_avg=transformed_rdd10.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))


# collecting them:

transformed_rdd3_avg_coll=transformed_rdd3_avg.collect()
transformed_rdd4_avg_coll=transformed_rdd4_avg.collect()
transformed_rdd5_avg_coll=transformed_rdd5_avg.collect()
transformed_rdd6_avg_coll=transformed_rdd6_avg.collect()

transformed_rdd7_avg_coll=transformed_rdd7_avg.collect()
transformed_rdd8_avg_coll=transformed_rdd8_avg.collect()
transformed_rdd9_avg_coll=transformed_rdd9_avg.collect()
transformed_rdd10_avg_coll=transformed_rdd10_avg.collect()


#time  = datetime.datetime.now().strftime("%y%m%d-%H%M")


# Task vi:

with open("shiva.pickle", 'wb') as f:

    pickle.dump(transformed_rdd3_coll, f)
    pickle.dump(transformed_rdd4_coll, f)
    pickle.dump(transformed_rdd5_coll, f)
    pickle.dump(transformed_rdd6_coll, f)
    pickle.dump(transformed_rdd7_coll, f)
    pickle.dump(transformed_rdd8_coll, f)
    pickle.dump(transformed_rdd9_coll, f)
    pickle.dump(transformed_rdd10_coll, f)


    pickle.dump(transformed_rdd3_avg_coll, f)
    pickle.dump(transformed_rdd4_avg_coll, f)
    pickle.dump(transformed_rdd5_avg_coll, f)
    pickle.dump(transformed_rdd6_avg_coll, f)
    pickle.dump(transformed_rdd7_avg_coll, f)
    pickle.dump(transformed_rdd8_avg_coll, f)
    pickle.dump(transformed_rdd9_avg_coll, f)
    pickle.dump(transformed_rdd10_avg_coll, f)
f.close()
subprocess.run(["gsutil","cp","shiva.pickle",BUCKET+"/shiva.pickle"],check=True)

end_time = time.time()-start_time

print('time in seconds without cache: ',end_time)
# Out:
# Writing spark_job.py

# %%
# %run ./spark_job.py
# Out:
# Tensorflow version 2.12.0
# [((2, 3, 1), 13.437582563805737), ((2, 6, 1), 13.869403163983169), ((4, 3, 1), 12.296378709223008), ((4, 6, 1), 15.283960338313186)]
# [((2, 3, 1), 7.494488090958932), ((2, 6, 1), 16.361806104805105), ((4, 3, 1), 17.300379475334104), ((4, 6, 1), 20.564236723263793)]
# time in seconds without cashe:  260.92428517341614

# %% [markdown]
# ### 2b) Testing the code and collecting results (4%)
#
# i) First, test locally with `%run`.
#
# It is useful to create a **new filename argument**, so that old results don't get overwritten.
#
# You can for instance use `datetime.datetime.now().strftime("%y%m%d-%H%M")` to get a string with the current date and time and use that in the file name.

# %%
### CODING TASK
# Task i:
# %run "spark_job.py"
# Out:
# Tensorflow version 2.12.0
# [((2, 3, 1), 3.091689898115783), ((2, 6, 1), 4.637495108584134), ((4, 3, 1), 3.7694945313038293), ((4, 6, 1), 5.982739179893519)]
# [((2, 3, 1), 4.6715711762451), ((2, 6, 1), 4.68093214553958), ((4, 3, 1), 4.759063222363706), ((4, 6, 1), 5.074781305311402)]

# %%
# !ls
# Out:
# shiva-230423-1722.pickle  shiva.pickle	spark-3.2.0-bin-hadoop2.7  spark_job.py

# %% [markdown]
# ii) Cloud
#
# If  you have a cluster running, you can run the  speed test job in the cloud.
#
# While you run this job, switch to the Dataproc web page and take **screenshots of the CPU and network load** over time. They are displayed with some delay, so you may need to wait a little. These images will be useful in the next task. Again, don't use the SCREENSHOT function that Google provides, but just take a picture of the graphs you see for the VMs.

# %%
size=2000//7
CLUSTER = '{}-maximal-cluster-4-workers'.format(PROJECT)
# !gcloud dataproc clusters create $CLUSTER \
--bucket $PROJECT-storage \
--num-workers=4 \
--metadata PIP_PACKAGES="tensorflow numpy scipy matplotlib"\
--master-machine-type=n1-standard-8 \
--worker-machine-type=n1-standard-2 \
--worker-boot-disk-type pd-standard --worker-boot-disk-size $size \
--master-boot-disk-type pd-ssd --master-boot-disk-size 300 \
--image-version=1.4-ubuntu18 \
--initialization-actions gs://goog-dataproc-initialization-actions-$REGION/python/pip-install.sh
# Out:
# Waiting on operation [projects/big-data-adcy439/regions/us-central1/operations/b2e06f79-39e8-329b-885c-8423e9f2d242].
#
# WARNING: Don't create production clusters that reference initialization actions located in the gs://goog-dataproc-initialization-actions-REGION public buckets. These scripts are provided as reference implementations, and they are synchronized with ongoing GitHub repository changes—a new version of a initialization action in public buckets may break your cluster creation. Instead, copy the following initialization actions from public buckets into your bucket : gs://goog-dataproc-initialization-actions-us-central1/python/pip-install.sh
# WARNING: Failed to validate permissions required for default service account: '175564710579-compute@developer.gserviceaccount.com'. Cluster creation could still be successful if required permissions have been granted to the respective service accounts as mentioned in the document https://cloud.google.com/dataproc/docs/concepts/configuring-clusters/service-accounts#dataproc_service_accounts_2. This could be due to Cloud Resource Manager API hasn't been enabled in your project '175564710579' before or it is disabled. Enable it by visiting 'https://console.developers.google.com/apis/api/cloudresourcemanager.googleapis.com/overview?project=175564710579'.
# WARNING: For PD-Standard without local SSDs, we strongly recommend provisioning 1TB or larger to ensure consistently high I/O performance. See https://cloud.google.com/compute/docs/disks/performance for information on disk I/O performance.
# Created [https://dataproc.googleapis.com/v1/projects/big-data-adcy439/regions/us-central1/clusters/big-data-adcy439-maximal-cluster-4-workers] Cluster placed in zone [us-central1-b].

# %%
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_job.py
# Out:
# Job [0573e1830c3a4ba1bc1f24c28c9948fb] submitted.
# Waiting for job output...
# 2023-05-05 17:18:46.570972: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 17:18:46.571016: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.6.2
# 23/05/05 17:18:48 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 17:18:49 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 17:18:49 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 17:18:49 INFO org.spark_project.jetty.util.log: Logging initialized @5841ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 17:18:49 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 17:18:49 INFO org.spark_project.jetty.server.Server: Started @5954ms
# 23/05/05 17:18:49 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@204d89e4{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 17:18:49 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 17:18:50 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-maximal-cluster-4-workers-m/10.128.0.52:8032
# 23/05/05 17:18:50 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-maximal-cluster-4-workers-m/10.128.0.52:10200
# 23/05/05 17:18:53 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683306982215_0001
# 2023-05-05 17:19:04.479272: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 17:19:04.479313: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-05 17:19:04.479335: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (big-data-adcy439-maximal-cluster-4-workers-m): /proc/driver/nvidia/version does not exist
# 2023-05-05 17:19:04.479740: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [((2, 3, 1), 8.981116184322943), ((2, 3, 2), 8.645416272138515), ((2, 3, 5), 9.195244919376814), ((2, 3, 9), 8.830383843859558), ((2, 6, 1), 7.639216171962794), ((2, 6, 2), 8.597990653621785), ((2, 6, 5), 8.362683031297852), ((2, 6, 9), 8.373427622959557), ((2, 9, 1), 9.41456902837272), ((2, 9, 2), 9.308783231012146), ((2, 9, 5), 9.642639915748328), ((2, 9, 9), 9.491830606650279), ((2, 15, 1), 11.257423550215233), ((2, 15, 2), 10.310570926780388), ((2, 15, 5), 10.265604583437971), ((2, 15, 9), 10.181049012320154), ((4, 3, 1), 7.978497282675893), ((4, 3, 2), 8.84977107456986), ((4, 3, 5), 8.289159880852196), ((4, 3, 9), 8.651977131864927), ((4, 6, 1), 9.387350954105415), ((4, 6, 2), 9.701158643338532), ((4, 6, 5), 9.962277386701194), ((4, 6, 9), 10.010890082269094), ((4, 9, 1), 11.266217853270431), ((4, 9, 2), 10.581388392252471), ((4, 9, 5), 10.809954979344267), ((4, 9, 9), 10.466113012553311), ((4, 15, 1), 14.412061271904513), ((4, 15, 2), 14.607224619932968), ((4, 15, 5), 14.756749981541228), ((4, 15, 9), 15.09666023173136), ((6, 3, 1), 9.353196967827394), ((6, 3, 2), 9.394015320641724), ((6, 3, 5), 9.487725683600273), ((6, 3, 9), 9.055985992804358), ((6, 6, 1), 10.435289432789164), ((6, 6, 2), 10.244632378491291), ((6, 6, 5), 10.53468951921871), ((6, 6, 9), 10.472732153171739), ((6, 9, 1), 10.79267057350598), ((6, 9, 2), 10.661026461945733), ((6, 9, 5), 10.91523355656462), ((6, 9, 9), 11.009641716578535), ((6, 15, 1), 11.46335699510178), ((6, 15, 2), 11.245056334756317), ((6, 15, 5), 11.204736864242992), ((6, 15, 9), 11.952712003180745), ((8, 3, 1), 9.574493608050606), ((8, 3, 2), 9.95211227436274), ((8, 3, 5), 9.936215477170858), ((8, 3, 9), 11.943399227084118), ((8, 6, 1), 10.584218034481697), ((8, 6, 2), 10.794649103514683), ((8, 6, 5), 10.163632124048501), ((8, 6, 9), 14.275222290258881), ((8, 9, 1), 10.62844914401869), ((8, 9, 2), 11.386126675579598), ((8, 9, 5), 10.956663972258726), ((8, 9, 9), 10.869065636146509), ((8, 15, 1), 15.889209398653682), ((8, 15, 2), 15.71060083649065), ((8, 15, 5), 15.652616514377987), ((8, 15, 9), 15.903918883790952)]
# [((2, 3, 1), 6.8265648163343915), ((2, 3, 2), 4.683467857288159), ((2, 3, 5), 8.41210301334862), ((2, 3, 9), 7.921118317392949), ((2, 6, 1), 6.819548171288217), ((2, 6, 2), 9.135067949464062), ((2, 6, 5), 9.416361526258246), ((2, 6, 9), 9.515981290194556), ((2, 9, 1), 7.12180841505214), ((2, 9, 2), 7.032436997399705), ((2, 9, 5), 9.39115719176623), ((2, 9, 9), 10.577156603683116), ((2, 15, 1), 8.644457430266433), ((2, 15, 2), 9.839411224533091), ((2, 15, 5), 7.636079664813879), ((2, 15, 9), 7.7393682588307735), ((4, 3, 1), 9.305800061827094), ((4, 3, 2), 9.167763227791298), ((4, 3, 5), 9.104827338028517), ((4, 3, 9), 8.818125158863893), ((4, 6, 1), 9.317739604826368), ((4, 6, 2), 6.7894466614408255), ((4, 6, 5), 10.215379652791096), ((4, 6, 9), 10.219963556805238), ((4, 9, 1), 7.0152467788601705), ((4, 9, 2), 10.350747321535055), ((4, 9, 5), 9.606748845061153), ((4, 9, 9), 9.292413094006427), ((4, 15, 1), 5.861691984123243), ((4, 15, 2), 5.861587872556106), ((4, 15, 5), 6.773633647621682), ((4, 15, 9), 11.835971087454805), ((6, 3, 1), 10.233752425175549), ((6, 3, 2), 10.150077648363531), ((6, 3, 5), 10.488506074620242), ((6, 3, 9), 10.681300989278744), ((6, 6, 1), 7.037942726473782), ((6, 6, 2), 11.872916729760933), ((6, 6, 5), 9.743373510598264), ((6, 6, 9), 9.205220313510116), ((6, 9, 1), 10.877400816394276), ((6, 9, 2), 7.508017081115078), ((6, 9, 5), 10.289723475113588), ((6, 9, 9), 9.449817226225802), ((6, 15, 1), 9.297015912615665), ((6, 15, 2), 10.536371598298519), ((6, 15, 5), 10.684408292818883), ((6, 15, 9), 10.508998550763877), ((8, 3, 1), 10.200067788813023), ((8, 3, 2), 9.539203085383994), ((8, 3, 5), 10.428377987240706), ((8, 3, 9), 9.737913952614122), ((8, 6, 1), 9.380444621871245), ((8, 6, 2), 9.365739367605636), ((8, 6, 5), 10.707920149188597), ((8, 6, 9), 10.28928828545194), ((8, 9, 1), 10.012646794212827), ((8, 9, 2), 8.72663809049245), ((8, 9, 5), 9.606657753773995), ((8, 9, 9), 12.194109849726992), ((8, 15, 1), 5.858681973346675), ((8, 15, 2), 7.609949343759623), ((8, 15, 5), 11.761331534513094), ((8, 15, 9), 10.894216111458295)]
# ERROR: Python 2 is not compatible with the Google Cloud SDK. Please use Python version 3.5 and up.
#
# If you have a compatible Python interpreter installed, you can use it by setting
# the CLOUDSDK_PYTHON environment variable to point to it.
#
# Traceback (most recent call last):
#   File "/tmp/0573e1830c3a4ba1bc1f24c28c9948fb/spark_job.py", line 276, in <module>
#     subprocess.run(["gsutil","cp","shiva.pickle",BUCKET+"/shiva.pickle"],check=True)
#   File "/opt/conda/default/lib/python3.6/subprocess.py", line 438, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['gsutil', 'cp', 'shiva.pickle', 'gs://big-data-adcy439-storage/shiva.pickle']' returned non-zero exit status 1.
# 23/05/05 18:48:31 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@204d89e4{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# ERROR: (gcloud.dataproc.jobs.submit.pyspark) Job [0573e1830c3a4ba1bc1f24c28c9948fb] failed with error:
# Google Cloud Dataproc Agent reports job failure. If logs are available, they can be found at:
# https://console.cloud.google.com/dataproc/jobs/0573e1830c3a4ba1bc1f24c28c9948fb?project=big-data-adcy439&region=us-central1
# gcloud dataproc jobs wait '0573e1830c3a4ba1bc1f24c28c9948fb' --region 'us-central1' --project 'big-data-adcy439'
# https://console.cloud.google.com/storage/browser/big-data-adcy439-storage/google-cloud-dataproc-metainfo/4ffa7131-54d6-41f9-b4eb-3f6c8f74257c/jobs/0573e1830c3a4ba1bc1f24c28c9948fb/
# gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4ffa7131-54d6-41f9-b4eb-3f6c8f74257c/jobs/0573e1830c3a4ba1bc1f24c28c9948fb/driveroutput

# %%
# !gcloud dataproc clusters delete $CLUSTER -q
# Out:
# Waiting on operation [projects/big-data-adcy439/regions/us-central1/operations/192b8c12-8afe-3143-8ab8-97ae3a304901].
# Deleted [https://dataproc.googleapis.com/v1/projects/big-data-adcy439/regions/us-central1/clusters/big-data-adcy439-maximal-cluster-4-workers].

# %% [markdown]
# ### 2c) Improve efficiency (6%)
#
# If you implemented a straightfoward version of 2a), you will **probably have an inefficiency** in your code.
#
# Because we are reading multiple times from an RDD to read the values for the different parameters and their averages, caching existing results is important. Explain **where in the process caching can help**, and **add a call to `RDD.cache()`** to your code, if you haven't yet. Measure the the effect of using caching or not using it.
#
# Make the **suitable change** in the code you have written above and mark them up in comments as `### TASK 3b ###`.
#
# Explain in your report what the **reasons for this change** are and **demonstrate and interpret its effect**

# %%
# Task vii :
# %%writefile spark_job_cache.py
import os, sys, math
import numpy as np
import scipy as sp
import scipy.stats
import time
import datetime
import string
import random
import pyspark 
from matplotlib import pyplot as plt
import tensorflow as tf
print("Tensorflow version " + tf.__version__)
import pickle
import subprocess


def decode_jpeg_and_label(filepath):
    # extracts the image data and creates a class label, based on the filepath 
    bits = tf.io.read_file(filepath)
    image = tf.image.decode_jpeg(bits)
    # parse flower name from containing directory
    label = tf.strings.split(tf.expand_dims(filepath, axis=-1), sep='/')
    label2 = label.values[-2]
    return image, label2

def resize_and_crop_image(image, label):
    # Resizes and cropd using "fill" algorithm:
    # always make sure the resulting image is cut out from the source image 
    # so that it fills the TARGET_SIZE entirely with no black bars 
    # and a preserved aspect ratio.
    w = tf.shape(image)[0]
    h = tf.shape(image)[1]
    tw = TARGET_SIZE[1]
    th = TARGET_SIZE[0]
    resize_crit = (w * th) / (h * tw)
    image = tf.cond(resize_crit < 1,
                    lambda: tf.image.resize(image, [w*tw/w, h*tw/w]), # if true
                    lambda: tf.image.resize(image, [w*th/h, h*th/h])  # if false
                    )
    nw = tf.shape(image)[0]
    nh = tf.shape(image)[1]
    image = tf.image.crop_to_bounding_box(image, (nw - tw) // 2, (nh - th) // 2, tw, th)
    return image, label

def recompress_image(image, label):
    # this reduces the amount of data, but takes some time
    image = tf.cast(image, tf.uint8)
    image = tf.image.encode_jpeg(image, optimize_size=True, chroma_downsampling=False)
    return image, label




def read_tfrecord(example):
    features = {
        "image": tf.io.FixedLenFeature([], tf.string),  # tf.string = bytestring (not text string)
        "class": tf.io.FixedLenFeature([], tf.int64) #,   # shape [] means scalar
    }
    # decode the TFRecord
    example = tf.io.parse_single_example(example, features)
    image = tf.image.decode_jpeg(example['image'], channels=3)
    image = tf.reshape(image, [*TARGET_SIZE, 3])    
    class_num = example['class']
    return image, class_num 


def load_dataset(filenames):
    # read from TFRecords. For optimal performance, read from multiple    
    # TFRecord files at once and set the option experimental_deterministic = False
    # to allow order-altering optimizations.
    option_no_order = tf.data.Options()
    option_no_order.experimental_deterministic = False

    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.with_options(option_no_order)
    dataset = dataset.map(read_tfrecord)
    return dataset

# Task ii:
#  first, lets create a function for performing timing test for only one parameter combination:
def time_config(params):
    bs, ds, rep = params
    with open("/dev/null", mode="w") as null_file:

        dsetFiles = tf.data.Dataset.list_files(GCS_PATTERN) 
        dsetDecoded = dsetFiles.map(decode_jpeg_and_label)
        dsetResized = dsetDecoded.map(resize_and_crop_image)  
        dataset = dsetResized.map(recompress_image) # creating the dataset( same as we did in task i)
      
        batched_dataset = dataset.batch(bs)
        timing_set = batched_dataset.take(ds)
        results = []
        for i in range(rep):
            t0 = time.time()
            for image, label in timing_set:
                print("Image batch shape {}, {})".format(image.numpy().shape, [str(lbl) for lbl in label.numpy()]), null_file)
            td = time.time() - t0
            results.append((bs * ds) / td)
        return (params,sum(results) / rep)



def time_config_tfrec(params):
    bs, ds, rep = params
    with open("/dev/null", mode="w") as null_file:
        filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
        dataset = load_dataset(filenames) # creating the dataset( same as we did in task i)
      
        batched_dataset = dataset.batch(bs)
        timing_set = batched_dataset.take(ds)
        results = []
        for i in range(rep):
            t0 = time.time()
            for image, label in timing_set:
                print("Image batch shape {}, {})".format(image.numpy().shape, [str(lbl) for lbl in label.numpy()]), null_file)
            td = time.time() - t0
            results.append((bs * ds) / td)
        return (params,sum(results) / rep)

PROJECT = 'big-data-adcy439'
BUCKET = 'gs://{}-storage'.format(PROJECT)

GCS_PATTERN = 'gs://flowers-public/*/*.jpg' # glob  pattern for input files
PARTITIONS = 16 # no of partitions we will use later 
TARGET_SIZE = [192, 192] # target resolution for the images
CLASSES = [b'daisy', b'dandelion', b'roses', b'sunflowers', b'tulips']

batch_sizes = [2,4,6,8] 
batch_numbers = [3,6,9,15] 
repetitions = [1,2,5,9]

PARTITIONS = 16 # no of partitions we will use later

sc = pyspark.SparkContext.getOrCreate()


start_time = time.time()
# Task i:
dsetFiles = tf.data.Dataset.list_files(GCS_PATTERN) 
dsetDecoded = dsetFiles.map(decode_jpeg_and_label)
dsetResized = dsetDecoded.map(resize_and_crop_image)  
dsetRecompressed = dsetResized.map(recompress_image) # creating the dataset

GCS_OUTPUT = BUCKET + '/tfrecords-jpeg-192x192-2-test/flowers'

filenames = tf.io.gfile.glob(GCS_OUTPUT + "*.tfrec")
datasetTfrec = load_dataset(filenames)

# Creating a list of  of parameter combinations in an RDD
 
param_Rdd = sc.parallelize([(bs, ds, rep) for bs in batch_sizes for ds in batch_numbers for rep in repetitions], 16)


#We add cache before the actions

# Now, we run the timing test for each combination in pararell
results_img_rdd = param_Rdd.map(time_config).cache()   #### TASK 3b ####

results_tf_rdd = param_Rdd.map(time_config_tfrec).cache()


# Collecting the results 
results = results_img_rdd.collect()
print(results)

results = results_tf_rdd.collect()
print(results)

# Task iii: 
transformed_img_rdd=results_img_rdd.map(lambda x:(x[0],x[0][0]*x[0][1]/x[1]))
transformed_tf_rdd=results_tf_rdd.map(lambda x:(x[0],x[0][0]*x[0][1]/x[1]))

transformed_img_rdd.collect()
transformed_tf_rdd.collect()

# Task iv:

# for images
transformed_img_bn=transformed_img_rdd.map(lambda x:(x[0][1],x[1]))
transformed_img_bs=transformed_img_rdd.map(lambda x:(x[0][0],x[1]))
transformed_img_rep=transformed_img_rdd.map(lambda x:(x[0][2],x[1]))
transformed_img_ds=transformed_img_rdd.map(lambda x:(x[0][0]*x[0][1],x[1]))

transformed_img_bn.collect()
transformed_img_bs.collect()
transformed_img_rep.collect()
transformed_img_ds.collect()

# for tfrecord files
transformed_tf_bn=transformed_tf_rdd.map(lambda x:(x[0][1],x[1]))
transformed_tf_bs=transformed_tf_rdd.map(lambda x:(x[0][0],x[1]))
transformed_tf_rep=transformed_tf_rdd.map(lambda x:(x[0][2],x[1]))
transformed_tf_ds=transformed_tf_rdd.map(lambda x:(x[0][0]*x[0][1],x[1]))

transformed_tf_bn.collect()
transformed_tf_bs.collect()
transformed_tf_rep.collect()
transformed_tf_ds.collect()
# print(transformed_rdd.collect())

# Task v:

transformed_rdd3=transformed_img_bn.groupByKey().mapValues(list)
transformed_rdd4=transformed_img_bs.groupByKey().mapValues(list)
transformed_rdd5=transformed_img_rep.groupByKey().mapValues(list)
transformed_rdd6=transformed_img_ds.groupByKey().mapValues(list)


transformed_rdd7=transformed_tf_bn.groupByKey().mapValues(list)
transformed_rdd8=transformed_tf_bs.groupByKey().mapValues(list)
transformed_rdd9=transformed_tf_rep.groupByKey().mapValues(list)
transformed_rdd10=transformed_tf_ds.groupByKey().mapValues(list)

# collecting them :

transformed_rdd3_coll=transformed_rdd3.collect()
transformed_rdd4_coll=transformed_rdd4.collect()
transformed_rdd5_coll=transformed_rdd5.collect()
transformed_rdd6_coll=transformed_rdd6.collect()

transformed_rdd7_coll=transformed_rdd7.collect()
transformed_rdd8_coll=transformed_rdd8.collect()
transformed_rdd9_coll=transformed_rdd9.collect()
transformed_rdd10_coll=transformed_rdd10.collect()

# getting the averages:

transformed_rdd3_avg=transformed_rdd3.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd4_avg=transformed_rdd4.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd5_avg=transformed_rdd5.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd6_avg=transformed_rdd6.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))

transformed_rdd7_avg=transformed_rdd7.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd8_avg=transformed_rdd8.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd9_avg=transformed_rdd9.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))
transformed_rdd10_avg=transformed_rdd10.map(lambda x: (x[0],(sum(x[1])/len(x[1]))))


# collecting them:

transformed_rdd3_avg_coll=transformed_rdd3_avg.collect()
transformed_rdd4_avg_coll=transformed_rdd4_avg.collect()
transformed_rdd5_avg_coll=transformed_rdd5_avg.collect()
transformed_rdd6_avg_coll=transformed_rdd6_avg.collect()

transformed_rdd7_avg_coll=transformed_rdd7_avg.collect()
transformed_rdd8_avg_coll=transformed_rdd8_avg.collect()
transformed_rdd9_avg_coll=transformed_rdd9_avg.collect()
transformed_rdd10_avg_coll=transformed_rdd10_avg.collect()


#time  = datetime.datetime.now().strftime("%y%m%d-%H%M")

# Task vi:

with open("shiva2.pickle", 'wb') as f:

    pickle.dump(transformed_rdd3_coll, f)
    pickle.dump(transformed_rdd4_coll, f)
    pickle.dump(transformed_rdd5_coll, f)
    pickle.dump(transformed_rdd6_coll, f)
    pickle.dump(transformed_rdd7_coll, f)
    pickle.dump(transformed_rdd8_coll, f)
    pickle.dump(transformed_rdd9_coll, f)
    pickle.dump(transformed_rdd10_coll, f)


    pickle.dump(transformed_rdd3_avg_coll, f)
    pickle.dump(transformed_rdd4_avg_coll, f)
    pickle.dump(transformed_rdd5_avg_coll, f)
    pickle.dump(transformed_rdd6_avg_coll, f)
    pickle.dump(transformed_rdd7_avg_coll, f)
    pickle.dump(transformed_rdd8_avg_coll, f)
    pickle.dump(transformed_rdd9_avg_coll, f)
    pickle.dump(transformed_rdd10_avg_coll, f)
f.close()
subprocess.run(["gsutil","cp","shiva2.pickle",BUCKET+"/shiva2.pickle"],check=True)

end_time = time.time()-start_time

print('cache time in seconds: ',end_time)
# Out:
# Overwriting spark_job_cache.py

# %%
# %run ./spark_job_cache.py
# Out:
# Tensorflow version 2.12.0
# [((2, 3, 1), 8.698960825366605), ((2, 3, 2), 10.929185717921193), ((2, 3, 5), 9.796252847398705), ((2, 3, 9), 11.490152310410664), ((2, 6, 1), 15.363070926347888), ((2, 6, 2), 17.14804221148738), ((2, 6, 5), 12.39549772916887), ((2, 6, 9), 18.45731659251225), ((2, 9, 1), 18.438567839472118), ((2, 9, 2), 21.734732020992457), ((2, 9, 5), 19.53036988336651), ((2, 9, 9), 19.596412785891445), ((2, 15, 1), 24.48757212480167), ((2, 15, 2), 20.521627582214748), ((2, 15, 5), 20.6677929010403), ((2, 15, 9), 22.152721633755835), ((4, 3, 1), 17.168538497984564), ((4, 3, 2), 17.906076429048554), ((4, 3, 5), 11.796201585911717), ((4, 3, 9), 19.3326928295914), ((4, 6, 1), 22.11846372018357), ((4, 6, 2), 23.890225097387315), ((4, 6, 5), 21.34754077612093), ((4, 6, 9), 18.946084953669963), ((4, 9, 1), 25.74651519478914), ((4, 9, 2), 22.919019139292573), ((4, 9, 5), 18.65814797751783), ((4, 9, 9), 22.73851045172134), ((4, 15, 1), 20.174556104152614), ((4, 15, 2), 22.476145086614324), ((4, 15, 5), 24.975120413617002), ((4, 15, 9), 25.148162354371166), ((6, 3, 1), 19.79354043051212), ((6, 3, 2), 21.17899096068378), ((6, 3, 5), 14.561133063272342), ((6, 3, 9), 20.67545317040195), ((6, 6, 1), 17.74081632341346), ((6, 6, 2), 17.167572118834972), ((6, 6, 5), 26.20072993210706), ((6, 6, 9), 22.8480165750877), ((6, 9, 1), 28.1598688663514), ((6, 9, 2), 19.880638644553255), ((6, 9, 5), 27.640268339036634), ((6, 9, 9), 23.831615215329517), ((6, 15, 1), 28.786629257284673), ((6, 15, 2), 23.2329328115715), ((6, 15, 5), 25.271481106999836), ((6, 15, 9), 24.523448982997767), ((8, 3, 1), 15.012611164775537), ((8, 3, 2), 21.227695361340327), ((8, 3, 5), 23.51247378011981), ((8, 3, 9), 18.176786049229754), ((8, 6, 1), 25.838238313880424), ((8, 6, 2), 17.12951356930395), ((8, 6, 5), 25.885344634628744), ((8, 6, 9), 24.054418616670795), ((8, 9, 1), 27.889560292506637), ((8, 9, 2), 19.424259451625247), ((8, 9, 5), 24.599693340220206), ((8, 9, 9), 25.667473355965868), ((8, 15, 1), 21.6040876874897), ((8, 15, 2), 26.473553379362034), ((8, 15, 5), 28.311259276741204), ((8, 15, 9), 33.424251645676044)]
# [((2, 3, 1), 15.97993445679209), ((2, 3, 2), 16.21649382579175), ((2, 3, 5), 16.33213758866777), ((2, 3, 9), 15.268109073196817), ((2, 6, 1), 18.265090251921528), ((2, 6, 2), 18.376987727177678), ((2, 6, 5), 17.592262834121616), ((2, 6, 9), 16.530499679366926), ((2, 9, 1), 14.655411968689556), ((2, 9, 2), 17.925010207858648), ((2, 9, 5), 20.827065910414635), ((2, 9, 9), 17.86249495028046), ((2, 15, 1), 19.877655908308437), ((2, 15, 2), 17.24144044630126), ((2, 15, 5), 18.02648218184607), ((2, 15, 9), 19.03568222812337), ((4, 3, 1), 18.750709415245137), ((4, 3, 2), 18.9658724642401), ((4, 3, 5), 20.215929448289337), ((4, 3, 9), 17.46881873755682), ((4, 6, 1), 18.036791269231774), ((4, 6, 2), 20.698165301034365), ((4, 6, 5), 20.18618202606922), ((4, 6, 9), 17.4919566804013), ((4, 9, 1), 20.346361099904517), ((4, 9, 2), 20.054795771952357), ((4, 9, 5), 17.1784262995061), ((4, 9, 9), 18.206548026728072), ((4, 15, 1), 19.617274172928813), ((4, 15, 2), 15.784373980882368), ((4, 15, 5), 17.89653946685446), ((4, 15, 9), 18.638741911770353), ((6, 3, 1), 19.37166279861905), ((6, 3, 2), 19.805124151619708), ((6, 3, 5), 13.75364982293622), ((6, 3, 9), 18.417674720449792), ((6, 6, 1), 11.009778833844551), ((6, 6, 2), 15.635077484092134), ((6, 6, 5), 19.19950299332478), ((6, 6, 9), 18.068399171623955), ((6, 9, 1), 19.610772103249108), ((6, 9, 2), 20.656308680410312), ((6, 9, 5), 18.00847051064736), ((6, 9, 9), 18.331253522063548), ((6, 15, 1), 19.645073709223396), ((6, 15, 2), 17.73241444751593), ((6, 15, 5), 16.641590812524637), ((6, 15, 9), 18.231678236077887), ((8, 3, 1), 17.533964368165663), ((8, 3, 2), 20.091762912116216), ((8, 3, 5), 16.43584380101066), ((8, 3, 9), 18.47709713233376), ((8, 6, 1), 14.642679409133557), ((8, 6, 2), 19.55269199408133), ((8, 6, 5), 18.962122429012297), ((8, 6, 9), 21.071959112066143), ((8, 9, 1), 19.923453639176945), ((8, 9, 2), 19.818666646831353), ((8, 9, 5), 21.651113931873297), ((8, 9, 9), 21.40361112208075), ((8, 15, 1), 11.700208762734718), ((8, 15, 2), 21.228842145716598), ((8, 15, 5), 22.610685220187314), ((8, 15, 9), 24.095546698752894)]
# cache time in seconds:  824.4483942985535

# %%
# !gcloud dataproc jobs submit pyspark --cluster $CLUSTER spark_job_cache.py
# Out:
# Job [f8579257777c4899861f27e591c34641] submitted.
# Waiting for job output...
# 2023-05-05 19:10:54.351324: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 19:10:54.351372: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Tensorflow version 2.6.2
# 23/05/05 19:10:56 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/05/05 19:10:56 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/05/05 19:10:56 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator
# 23/05/05 19:10:56 INFO org.spark_project.jetty.util.log: Logging initialized @5271ms to org.spark_project.jetty.util.log.Slf4jLog
# 23/05/05 19:10:56 INFO org.spark_project.jetty.server.Server: jetty-9.4.z-SNAPSHOT; built: unknown; git: unknown; jvm 1.8.0_312-b07
# 23/05/05 19:10:56 INFO org.spark_project.jetty.server.Server: Started @5387ms
# 23/05/05 19:10:56 INFO org.spark_project.jetty.server.AbstractConnector: Started ServerConnector@71dbb1cc{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# 23/05/05 19:10:57 WARN org.apache.spark.scheduler.FairSchedulableBuilder: Fair Scheduler configuration file not found so jobs will be scheduled in FIFO order. To use fair scheduling, configure pools in fairscheduler.xml or set spark.scheduler.allocation.file to a file that contains the configuration.
# 23/05/05 19:10:57 INFO org.apache.hadoop.yarn.client.RMProxy: Connecting to ResourceManager at big-data-adcy439-maximal-cluster-4-workers-m/10.128.0.52:8032
# 23/05/05 19:10:58 INFO org.apache.hadoop.yarn.client.AHSProxy: Connecting to Application History server at big-data-adcy439-maximal-cluster-4-workers-m/10.128.0.52:10200
# 23/05/05 19:10:59 INFO org.apache.hadoop.yarn.client.api.impl.YarnClientImpl: Submitted application application_1683306982215_0003
# 2023-05-05 19:11:06.576013: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/lib/hadoop/lib/native
# 2023-05-05 19:11:06.576062: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-05 19:11:06.576083: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (big-data-adcy439-maximal-cluster-4-workers-m): /proc/driver/nvidia/version does not exist
# 2023-05-05 19:11:06.576608: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [((2, 3, 1), 4.8651619988868395), ((2, 3, 2), 7.255815562756032), ((2, 3, 5), 7.042039471561774), ((2, 3, 9), 6.70197255450078), ((2, 6, 1), 11.740964500432836), ((2, 6, 2), 12.471177427169227), ((2, 6, 5), 12.330055098046179), ((2, 6, 9), 12.526452083401441), ((2, 9, 1), 10.218890827460093), ((2, 9, 2), 9.291424543731907), ((2, 9, 5), 9.396563356727734), ((2, 9, 9), 9.254590716426774), ((2, 15, 1), 9.986331098833466), ((2, 15, 2), 10.30185237615214), ((2, 15, 5), 10.297946908623931), ((2, 15, 9), 9.983951327851482), ((4, 3, 1), 7.159112720116306), ((4, 3, 2), 8.127222277949684), ((4, 3, 5), 7.216771737938697), ((4, 3, 9), 6.883164217193013), ((4, 6, 1), 9.856252449662646), ((4, 6, 2), 10.700955538636897), ((4, 6, 5), 9.722973184964019), ((4, 6, 9), 9.85609186121009), ((4, 9, 1), 9.659696929975151), ((4, 9, 2), 9.27142490173234), ((4, 9, 5), 9.49733375252965), ((4, 9, 9), 8.923403352592794), ((4, 15, 1), 17.01754342070162), ((4, 15, 2), 17.642432803549468), ((4, 15, 5), 16.970614254453757), ((4, 15, 9), 17.31982714668318), ((6, 3, 1), 8.747347408421765), ((6, 3, 2), 8.754365896980188), ((6, 3, 5), 8.838649802691954), ((6, 3, 9), 8.10253270763109), ((6, 6, 1), 9.972232281011857), ((6, 6, 2), 9.216942917717127), ((6, 6, 5), 8.948607751788908), ((6, 6, 9), 9.117049273765787), ((6, 9, 1), 10.390921673041202), ((6, 9, 2), 10.829316272184583), ((6, 9, 5), 10.787320476670091), ((6, 9, 9), 10.600873831652688), ((6, 15, 1), 11.217725634128062), ((6, 15, 2), 10.970942444120084), ((6, 15, 5), 11.114775886426788), ((6, 15, 9), 16.544960065627915), ((8, 3, 1), 9.642004275829304), ((8, 3, 2), 9.48497987977111), ((8, 3, 5), 9.511113511856701), ((8, 3, 9), 9.891599858770542), ((8, 6, 1), 10.376831909331766), ((8, 6, 2), 10.873948423258707), ((8, 6, 5), 10.380411639120606), ((8, 6, 9), 15.867425215356668), ((8, 9, 1), 17.956613347811686), ((8, 9, 2), 17.62897824873615), ((8, 9, 5), 17.256505917885832), ((8, 9, 9), 17.900991718408577), ((8, 15, 1), 9.946192917455646), ((8, 15, 2), 11.122470752641831), ((8, 15, 5), 15.86993160357323), ((8, 15, 9), 15.477252073146694)]
# [((2, 3, 1), 4.66592133030304), ((2, 3, 2), 6.19004807921146), ((2, 3, 5), 6.727438946806318), ((2, 3, 9), 8.12605037551853), ((2, 6, 1), 10.701388519761307), ((2, 6, 2), 10.831986056576397), ((2, 6, 5), 11.107234441017201), ((2, 6, 9), 11.162846780925356), ((2, 9, 1), 8.961110445764298), ((2, 9, 2), 8.129651280007689), ((2, 9, 5), 9.51994249228664), ((2, 9, 9), 8.051030224460737), ((2, 15, 1), 9.427440269109862), ((2, 15, 2), 7.506435690311221), ((2, 15, 5), 8.106364032675094), ((2, 15, 9), 8.146731413314466), ((4, 3, 1), 4.662179770470425), ((4, 3, 2), 7.090780891174033), ((4, 3, 5), 7.068836119254021), ((4, 3, 9), 8.455974204351202), ((4, 6, 1), 9.148388528590868), ((4, 6, 2), 9.447140977053422), ((4, 6, 5), 9.169764818504579), ((4, 6, 9), 9.660193867794028), ((4, 9, 1), 9.637386243121485), ((4, 9, 2), 7.026883515873292), ((4, 9, 5), 9.743363980663869), ((4, 9, 9), 7.865092603176992), ((4, 15, 1), 5.853480174854812), ((4, 15, 2), 7.890467721537052), ((4, 15, 5), 8.736621751974551), ((4, 15, 9), 6.016457816379724), ((6, 3, 1), 11.325396589666392), ((6, 3, 2), 11.510412376179946), ((6, 3, 5), 11.534190106295792), ((6, 3, 9), 11.182511169380753), ((6, 6, 1), 9.228864306826129), ((6, 6, 2), 7.026446471864968), ((6, 6, 5), 9.621016023147046), ((6, 6, 9), 5.10219423487536), ((6, 9, 1), 10.568871945359575), ((6, 9, 2), 10.171417353890913), ((6, 9, 5), 5.264514128968135), ((6, 9, 9), 5.270490196934715), ((6, 15, 1), 10.500467947117595), ((6, 15, 2), 9.341157236510622), ((6, 15, 5), 4.390859846626821), ((6, 15, 9), 5.696261076542706), ((8, 3, 1), 11.832315739697107), ((8, 3, 2), 11.688377468485992), ((8, 3, 5), 11.304502130526226), ((8, 3, 9), 8.776125199941285), ((8, 6, 1), 4.687263393436384), ((8, 6, 2), 4.674633963205695), ((8, 6, 5), 4.677801056814549), ((8, 6, 9), 7.802326748113166), ((8, 9, 1), 7.018396670286762), ((8, 9, 2), 7.019876136378233), ((8, 9, 5), 7.4994004650527755), ((8, 9, 9), 4.652000191983629), ((8, 15, 1), 5.857261523028287), ((8, 15, 2), 5.858006399752752), ((8, 15, 5), 5.857546336626105), ((8, 15, 9), 5.856678077092824)]
# cache time in seconds:  695.3803379535675
# 23/05/05 19:22:42 INFO org.spark_project.jetty.server.AbstractConnector: Stopped Spark@71dbb1cc{HTTP/1.1, (http/1.1)}{0.0.0.0:4040}
# Job [f8579257777c4899861f27e591c34641] finished successfully.
# done: true
# driverControlFilesUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4ffa7131-54d6-41f9-b4eb-3f6c8f74257c/jobs/f8579257777c4899861f27e591c34641/
# driverOutputResourceUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4ffa7131-54d6-41f9-b4eb-3f6c8f74257c/jobs/f8579257777c4899861f27e591c34641/driveroutput
# jobUuid: 57001d4f-b5c8-3954-a39a-8828abb50a27
# placement:
#   clusterName: big-data-adcy439-maximal-cluster-4-workers
#   clusterUuid: 4ffa7131-54d6-41f9-b4eb-3f6c8f74257c
# pysparkJob:
#   mainPythonFileUri: gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/4ffa7131-54d6-41f9-b4eb-3f6c8f74257c/jobs/f8579257777c4899861f27e591c34641/staging/spark_job_cache.py
# reference:
#   jobId: f8579257777c4899861f27e591c34641
#   projectId: big-data-adcy439
# status:
#   state: DONE
#   stateStartTime: '2023-05-05T19:22:43.532896Z'
# statusHistory:
# - state: PENDING
#   stateStartTime: '2023-05-05T19:10:49.915591Z'
# - state: SETUP_DONE
#   stateStartTime: '2023-05-05T19:10:49.956386Z'
# - details: Agent reported job success
#   state: RUNNING
#   stateStartTime: '2023-05-05T19:10:50.209768Z'
# yarnApplications:
# - name: spark_job_cache.py
#   progress: 1.0
#   state: FINISHED
#   trackingUrl: http://big-data-adcy439-maximal-cluster-4-workers-m:8088/proxy/application_1683306982215_0003/

# %%
# !gsutil ls $BUCKET
# Out:
# gs://big-data-adcy439-storage/shiva.pickle
# gs://big-data-adcy439-storage/shiva2.pickle
# gs://big-data-adcy439-storage/words.pkl
# gs://big-data-adcy439-storage/google-cloud-dataproc-metainfo/
# gs://big-data-adcy439-storage/library/
# gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2-test/
# gs://big-data-adcy439-storage/tfrecords-jpeg-192x192-2/
# gs://big-data-adcy439-storage/tfrecords-test/

# %% [markdown]
# ### 2d) Retrieve, analyse and discuss the output (12%)
#
# Run the tests over a wide range of different paramters and list the results in a table.
#
# Perform a **linear regression** (e.g. using scikit-learn) over **the values for each parameter** and for the **two cases** (reading from image files/reading TFRecord files).
# List a **table** with the output and interpret the results in terms of the effects of overall.
# Also, **plot** the output values, the averages per parameter value and the regression lines for each parameter and for the product of batch_size and batch_number
#
# Discuss the **implications** of this result for **applications** like large-scale machine learning.
# Keep in mind that cloud data may be stored in distant physical locations.
# Use the numbers provided in the PDF latency-numbers document available on Moodle or [here](https://gist.github.com/hellerbarde/2843375) for your arguments.
#
# How is the **observed** behaviour **similar or different** from what you’d expect from a **single machine**? Why would cloud providers tie throughput to capacity of disk resources?
#
# By **parallelising** the speed test we are making **assumptions** about the limits of the bucket reading speeds.
# See [here](https://cloud.google.com/storage/docs/request-rate) for more information.
# Discuss, **what we need to consider** in **speed tests** in parallel on the cloud, which bottlenecks we might be identifying, and how this relates to your results.
#
# Discuss to what extent **linear modelling** reflects the **effects** we are observing.
# Discuss what could be expected from a theoretical perspective and what can be useful in practice.
#
# Write your **code below** and **include the output** in your submitted `ipynb` file. Provide the answer **text in your report**.

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
### CODING TASK ### 
# !gsutil cp $BUCKET/shiva2.pickle .
with open("shiva2.pickle", 'rb') as f:
          transformed_rdd3_coll = pickle.load(f)
          transformed_rdd4_coll = pickle.load(f)
          transformed_rdd5_coll = pickle.load(f)
          transformed_rdd6_coll = pickle.load(f)
          transformed_rdd7_coll = pickle.load(f)
          transformed_rdd8_coll = pickle.load(f)
          transformed_rdd9_coll = pickle.load(f)
          transformed_rdd10_coll  =  pickle.load(f)
          transformed_rdd3_avg_coll = pickle.load(f) 
          transformed_rdd4_avg_coll = pickle.load(f) 
          transformed_rdd5_avg_coll = pickle.load(f) 
          transformed_rdd6_avg_coll = pickle.load(f) 
          transformed_rdd7_avg_coll = pickle.load(f) 
          transformed_rdd8_avg_coll = pickle.load(f) 
          transformed_rdd9_avg_coll = pickle.load(f) 
          transformed_rdd10_avg_coll =  pickle.load(f)
# Out:
# Copying gs://big-data-adcy439-storage/shiva2.pickle...
# / [1 files][  5.7 KiB/  5.7 KiB]
# Operation completed over 1 objects/5.7 KiB.

# %%
df_tfrecord_bsizes_speed['b_sizes']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-e4f0ee00f3e7> in <cell line: 1>()
# ----> 1 df_tfrecord_bsizes_speed['b_sizes']
#
# NameError: name 'df_tfrecord_bsizes_speed' is not defined

# %%
def plot_lg_result(transformed_coll, transformed_rdd_avg_coll, image_reader_type, paramerter):
  linreg_df_speed = LinearRegression()
  transformed_rdd_coll__temp=[(key,value) for key, values in transformed_coll for value in values]

  df_speed = pd.DataFrame(transformed_rdd_coll__temp, columns=[paramerter,"reading_speed"])
  df_avg_speed = pd.DataFrame(transformed_rdd_avg_coll, columns=[paramerter,"reading_speed"])
  linreg_df_speed.fit(df_speed[[paramerter]],df_speed['reading_speed'])

  reading_speed_predict = linreg_df_speed.predict(df_speed[[paramerter]])
  fig = plt.figure(figsize=(8,5))
  plt.scatter(df_speed[[paramerter]], df_speed['reading_speed'],label='Parameter Value', color='orange')
  plt.plot(df_speed[[paramerter]], reading_speed_predict, color='red', linestyle='dashed',label='Regression line')
  plt.plot(df_avg_speed[[paramerter]],df_avg_speed['reading_speed'],label='Average of Parameter Value', color='green')
  plt.title(image_reader_type + " - " + paramerter + " vs " + "Reading Speed for Image Per Second")

  plt.legend(loc='upper left')
  plt.ylabel('Reading Speed for Image Per Second')
  plt.xlabel(paramerter) 
  plt.show()

  print("Slope : ",linreg_df_speed.coef_)
  print("Intercept : ",linreg_df_speed.intercept_)
  print('P-value : ',linreg_df_speed.score(df_speed[[paramerter]],df_speed['reading_speed']))

# %% [markdown]
# Dataset Plot:

# %%
plot_lg_result(transformed_rdd3_coll, transformed_rdd3_avg_coll, "Dataset", "Batch Number")
# Out:
# Slope :  [0.1749617]
# Intercept :  0.3777278408874376
# P-value :  0.4813655509186334

# %%
plot_lg_result(transformed_rdd4_coll, transformed_rdd4_avg_coll, "Dataset", "Batch Size")
# Out:
# Slope :  [0.30107986]
# Intercept :  0.315762604576062
# P-value :  0.36201940326087845

# %%
plot_lg_result(transformed_rdd5_coll, transformed_rdd5_avg_coll, "Dataset", "Repetitions")
# Out:
# Slope :  [-0.02275534]
# Intercept :  1.9178720708366366
# P-value :  0.004006606785862066

# %%
plot_lg_result(transformed_rdd6_coll, transformed_rdd6_avg_coll, "Dataset", "Datasize")
# Out:
# Slope :  [0.03534086]
# Intercept :  0.36335143681771975
# P-value :  0.928695156313377

# %% [markdown]
# TFRecord Plot

# %%
plot_lg_result(transformed_rdd7_coll, transformed_rdd7_avg_coll, "TFRecord", "Batch Number")
# Out:
# Slope :  [0.27039549]
# Intercept :  0.02494740641134552
# P-value :  0.47428643500814116

# %%
plot_lg_result(transformed_rdd8_coll, transformed_rdd8_avg_coll, "TFRecord", "Batch Size")
# Out:
# Slope :  [0.43669623]
# Intercept :  0.07222906869448042
# P-value :  0.3141811515812536

# %%
plot_lg_result(transformed_rdd9_coll, transformed_rdd9_avg_coll, "TFRecord", "Repetitions")
# Out:
# Slope :  [-0.03912014]
# Intercept :  2.4219707894585945
# P-value :  0.004884989809062823

# %%
plot_lg_result(transformed_rdd10_coll, transformed_rdd10_avg_coll, "TFRecord", "Datasize")
# Out:
# Slope :  [0.05360207]
# Intercept :  0.044624695691315
# P-value :  0.8813226645454574

# %% [markdown]
# # Section 3. Theoretical discussion

# %% [markdown]
# ## Task 3: Discussion in context. (24%)
#
# > Indented block
#
#
#
# In this task we refer an idea that is introduced in this papers:
# -	Alipourfard, O., Liu, H. H., Chen, J., Venkataraman, S., Yu, M., & Zhang, M. (2017). [Cherrypick: Adaptively unearthing the best cloud configurations for big data analytics.](https://people.irisa.fr/Davide.Frey/wp-content/uploads/2018/02/cherrypick.pdf). In USENIX NSDI  17 (pp. 469-482).
#
# Alipourfard et al (2017) introduce  the prediction an optimal or near-optimal cloud configuration for a given compute task.
#
# ### 3a)	Contextualise
#
# Relate the previous tasks and the results to this concept. (It is not necessary to work through the full details of the papers, focus just on the main ideas). To what extent and under what conditions do the concepts and techniques in the paper apply to the task in this coursework? (12%)
#
# ### 3b)	Strategise
#
# Define - as far as possible - concrete strategies for different application scenarios (batch, stream) and discuss the general relationship with the concepts above. (12%)
#
# Provide the answers to these questions in your report.

# %% [markdown]
# ## Final cleanup
#
# Once you have finshed the work, you can delete the buckets, to stop incurring cost that depletes your credit.

# %%
# !gsutil -m rm -r $BUCKET/* # Empty your bucket 
# !gsutil rb $BUCKET # delete the bucket
